# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khetansarvesh/Convex-Unconstrained-NonLinear-Optimization-Algorithms/blob/main/Hookes-And-Jeeves-Algorithm.ipynb)

# %%
import math

# %%
def golden(m,n,d1,d2,lower_limit_of_interval=0,upper_limit_of_interval=1,critical_interval_length=0.00005):
  
  golden_ratio = 1.618
  L0 = upper_limit_of_interval-lower_limit_of_interval
  no_of_iterations = math.ceil(math.log2(L0/critical_interval_length)/math.log2(golden_ratio) +1 )

  for i in range(no_of_iterations-1):
      x1 = lower_limit_of_interval + (1/golden_ratio**2)*L0
      value_at_x1 = function(m+x1*d1,n+x1*d2)
      x2 = upper_limit_of_interval - (1/golden_ratio**2)*L0
      value_at_x2 = function(m+x2*d1,n+x2*d2)

      if value_at_x2 > value_at_x1:
        lower_limit_of_interval = lower_limit_of_interval
        upper_limit_of_interval = x2
      else:
        lower_limit_of_interval = x1
        upper_limit_of_interval = upper_limit_of_interval

      L0=upper_limit_of_interval-lower_limit_of_interval

  return (lower_limit_of_interval+upper_limit_of_interval)/2

# %%
def hookes_and_jeeves_algorithm():
  
  #initial random points initialization
  x1,x2 = 0,0

  iteration_no = 1
  while(True):
      print("*****************Iteration {}***************".format(iteration_no))
      print("Initial Points : [{},{}]".format(x1,x2))

      #traversing in direction (1,0)
      lambda1 = golden(x1,x2,1,0)
      x1_new1 = x1 + lambda1*1
      x2_new1 = x2 + lambda1*0
      print("New points after traversing in direction (1,0) with step size of {} is : [{},{}] ".format(lambda1,x1_new1,x2_new1))
          
      #traversing in direction (0,1)
      lambda2 = golden(x1_new1,x2_new1,0,1)
      x1_new2 = x1_new1 + lambda2*0
      x2_new2 = x2_new1 + lambda2*1
      print("New points after traversing in direction (0,1) with step size of {} is : [{},{}] ".format(lambda2,x1_new2,x2_new2))

      #traversing in direction (x1_new2-x1,x2_new2-x2)
      lambda3 = golden(x1_new2,x2_new2,x1_new2-x1,x2_new2-x2)
      x1_new3 = x1_new2 + lambda3*(x1_new2-x1)
      x2_new3 = x2_new2 + lambda3*(x2_new2-x2)
      print("New points after traversing in direction ({},{}) with step size of {} is : [{},{}] ".format(x1_new2-x1,x2_new2-x2,lambda3,x1_new3,x2_new3))
      print("")

      #convergence critera
      if ((x1_new3 - x1_new2)**2+(x2_new3 - x2_new2)**2)**0.5 < 0.000002:
        break	

      #preparing for next iteration    
      iteration_no = iteration_no + 1
      x1 = x1_new3
      x2 = x2_new3

  return x1,x2

# %%
def function(x1,x2):
    return (3 - x1)**2 + 7*((x2 - x1**2)**2)

x1,x2 = hookes_and_jeeves_algorithm()
# Out:
# *****************Iteration 1***************
# Initial Points : [0,0]
# New points after traversing in direction (1,0) with step size of 0.5586907384002677 is : [0.5586907384002677,0.0]
# New points after traversing in direction (0,1) with step size of 0.31212732649834385 is : [0.5586907384002677,0.31212732649834385]
# New points after traversing in direction (0.5586907384002677,0.31212732649834385) with step size of 0.5435491633350978 is : [0.8623666218208013,0.48178387367053954]
#
# *****************Iteration 2***************
# Initial Points : [0.8623666218208013,0.48178387367053954]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [0.8623870388590373,0.48178387367053954]
# New points after traversing in direction (0,1) with step size of 0.2619342721461221 is : [0.8623870388590373,0.7437181458166616]
# New points after traversing in direction (2.041703823607577e-05,0.2619342721461221) with step size of 6.125495105981977e-05 is : [0.862387040109682,0.7437341905876829]
#
# *****************Iteration 3***************
# Initial Points : [0.862387040109682,0.7437341905876829]
# New points after traversing in direction (1,0) with step size of 0.08543762280048989 is : [0.9478246629101719,0.7437341905876829]
# New points after traversing in direction (0,1) with step size of 0.15463935367730103 is : [0.9478246629101719,0.8983735442649838]
# New points after traversing in direction (0.08543762280048983,0.15463935367730097) with step size of 0.9999795829617639 is : [1.0332605413274503,1.0530097406646879]
#
# *****************Iteration 4***************
# Initial Points : [1.0332605413274503,1.0530097406646879]
# New points after traversing in direction (1,0) with step size of 0.05252984637104875 is : [1.0857903876984991,1.0530097406646879]
# New points after traversing in direction (0,1) with step size of 0.12594210433332897 is : [1.0857903876984991,1.178951844998017]
# New points after traversing in direction (0.05252984637104885,0.12594210433332909) with step size of 0.9999795829617639 is : [1.138319161565666,1.3048913779665863]
#
# *****************Iteration 5***************
# Initial Points : [1.138319161565666,1.3048913779665863]
# New points after traversing in direction (1,0) with step size of 0.0506764808329727 is : [1.1889956423986388,1.3048913779665863]
# New points after traversing in direction (0,1) with step size of 0.10881439083259065 is : [1.1889956423986388,1.413705768799177]
# New points after traversing in direction (0.050676480832972715,0.1088143908325907) with step size of 0.9999795829617639 is : [1.2396710885679647,1.5225179379641893]
#
# *****************Iteration 6***************
# Initial Points : [1.2396710885679647,1.5225179379641893]
# New points after traversing in direction (1,0) with step size of 0.032909589302463405 is : [1.272580677870428,1.5225179379641893]
# New points after traversing in direction (0,1) with step size of 0.09693687022263611 is : [1.272580677870428,1.6194548081868254]
# New points after traversing in direction (0.03290958930246335,0.09693687022263608) with step size of 0.9999795829617639 is : [1.3054895952565482,1.7163896992456757]
#
# *****************Iteration 7***************
# Initial Points : [1.3054895952565482,1.7163896992456757]
# New points after traversing in direction (1,0) with step size of 0.037826651729776284 is : [1.3433162469863245,1.7163896992456757]
# New points after traversing in direction (0,1) with step size of 0.0881151428626614 is : [1.3433162469863245,1.8045048421083372]
# New points after traversing in direction (0.037826651729776284,0.08811514286266142) with step size of 0.9999795829617639 is : [1.381142126407906,1.8926181859207576]
#
# *****************Iteration 8***************
# Initial Points : [1.381142126407906,1.8926181859207576]
# New points after traversing in direction (1,0) with step size of 0.023741039053556793 is : [1.4048831654614629,1.8926181859207576]
# New points after traversing in direction (0,1) with step size of 0.08107981934914821 is : [1.4048831654614629,1.9736980052699058]
# New points after traversing in direction (0.023741039053556845,0.08107981934914821) with step size of 0.9999795829617639 is : [1.4286237197933176,2.054776169209282]
#
# *****************Iteration 9***************
# Initial Points : [1.4286237197933176,2.054776169209282]
# New points after traversing in direction (1,0) with step size of 0.030883413205643997 is : [1.4595071329989615,2.054776169209282]
# New points after traversing in direction (0,1) with step size of 0.07538849610043238 is : [1.4595071329989615,2.1301646653097146]
# New points after traversing in direction (0.030883413205643917,0.07538849610043252) with step size of 0.9999795829617639 is : [1.4903899156567773,2.2055516222003395]
#
# *****************Iteration 10***************
# Initial Points : [1.4903899156567773,2.2055516222003395]
# New points after traversing in direction (1,0) with step size of 0.018304873098495475 is : [1.5086947887552726,2.2055516222003395]
# New points after traversing in direction (0,1) with step size of 0.07060131007655318 is : [1.5086947887552726,2.2761529322768927]
# New points after traversing in direction (0.018304873098495378,0.07060131007655324) with step size of 0.9999795829617639 is : [1.526999288122474,2.346752800883799]
#
# *****************Iteration 11***************
# Initial Points : [1.526999288122474,2.346752800883799]
# New points after traversing in direction (1,0) with step size of 0.02647498633247246 is : [1.5534742744549466,2.346752800883799]
# New points after traversing in direction (0,1) with step size of 0.06652412391830242 is : [1.5534742744549466,2.4132769248021013]
# New points after traversing in direction (0.026474986332472472,0.06652412391830254) with step size of 0.9999795829617639 is : [1.5799487202466107,2.479799690494822]
#
# *****************Iteration 12***************
# Initial Points : [1.5799487202466107,2.479799690494822]
# New points after traversing in direction (1,0) with step size of 0.014664587663774473 is : [1.5946133079103852,2.479799690494822]
# New points after traversing in direction (0,1) with step size of 0.06299110340206501 is : [1.5946133079103852,2.542790793896887]
# New points after traversing in direction (0.014664587663774542,0.06299110340206493) with step size of 0.9999795829617639 is : [1.6092775961667127,2.605780611207185]
#
# *****************Iteration 13***************
# Initial Points : [1.6092775961667127,2.605780611207185]
# New points after traversing in direction (1,0) with step size of 0.023394989034929186 is : [1.632672585201642,2.605780611207185]
# New points after traversing in direction (0,1) with step size of 0.05984448489364727 is : [1.632672585201642,2.6656250961008325]
# New points after traversing in direction (0.023394989034929203,0.059844484893647465) with step size of 0.9999795829617639 is : [1.6560670965801856,2.7254683591473436]
#
# *****************Iteration 14***************
# Initial Points : [1.6560670965801856,2.7254683591473436]
# New points after traversing in direction (1,0) with step size of 0.012012644265178923 is : [1.6680797408453645,2.7254683591473436]
# New points after traversing in direction (0,1) with step size of 0.05701918532596434 is : [1.6680797408453645,2.782487544473308]
# New points after traversing in direction (0.012012644265178896,0.05701918532596428) with step size of 0.9999795829617639 is : [1.680092139847926,2.8395055656363852]
#
# *****************Iteration 15***************
# Initial Points : [1.680092139847926,2.8395055656363852]
# New points after traversing in direction (1,0) with step size of 0.021089148257326624 is : [1.7011812881052526,2.8395055656363852]
# New points after traversing in direction (0,1) with step size of 0.05451502289843539 is : [1.7011812881052526,2.8940205885348207]
# New points after traversing in direction (0.02108914825732655,0.05451502289843546) with step size of 0.9999795829617639 is : [1.7222700057846327,2.948534498397949]
#
# *****************Iteration 16***************
# Initial Points : [1.7222700057846327,2.948534498397949]
# New points after traversing in direction (1,0) with step size of 0.010002120118865719 is : [1.7322721259034985,2.948534498397949]
# New points after traversing in direction (0,1) with step size of 0.052224612706444906 is : [1.7322721259034985,3.000759111104394]
# New points after traversing in direction (0.01000212011886581,0.05222461270644496) with step size of 0.9999795829617639 is : [1.7422740418086955,3.0529826575389247]
#
# *****************Iteration 17***************
# Initial Points : [1.7422740418086955,3.0529826575389247]
# New points after traversing in direction (1,0) with step size of 0.019317825339107607 is : [1.761591867147803,3.0529826575389247]
# New points after traversing in direction (0,1) with step size of 0.050223504915405545 is : [1.761591867147803,3.10320616245433]
# New points after traversing in direction (0.01931782533910753,0.05022350491540539) with step size of 0.9999795829617639 is : [1.780909298074132,3.153428641954515]
#
# *****************Iteration 18***************
# Initial Points : [1.780909298074132,3.153428641954515]
# New points after traversing in direction (1,0) with step size of 0.008429165252344769 is : [1.7893384633264766,3.153428641954515]
# New points after traversing in direction (0,1) with step size of 0.04830441344288666 is : [1.7893384633264766,3.2017330553974017]
# New points after traversing in direction (0.008429165252344717,0.048304413442886496) with step size of 0.9999795829617639 is : [1.7977674564802322,3.250036482607232]
#
# *****************Iteration 19***************
# Initial Points : [1.7977674564802322,3.250036482607232]
# New points after traversing in direction (1,0) with step size of 0.01789275665035676 is : [1.815660213130589,3.250036482607232]
# New points after traversing in direction (0,1) with step size of 0.046574003509561215 is : [1.815660213130589,3.2966104861167933]
# New points after traversing in direction (0.017892756650356834,0.0465740035095612) with step size of 0.9999795829617639 is : [1.8335526044638493,3.343183538723144]
#
# *****************Iteration 20***************
# Initial Points : [1.8335526044638493,3.343183538723144]
# New points after traversing in direction (1,0) with step size of 0.007136268139022287 is : [1.8406888726028716,3.343183538723144]
# New points after traversing in direction (0,1) with step size of 0.0449587659705509 is : [1.8406888726028716,3.388142304693695]
# New points after traversing in direction (0.00713626813902235,0.04495876597055082) with step size of 0.9999795829617639 is : [1.8478249950404344,3.433100152739402]
#
# *****************Iteration 21***************
# Initial Points : [1.8478249950404344,3.433100152739402]
# New points after traversing in direction (1,0) with step size of 0.016731492617063665 is : [1.864556487657498,3.433100152739402]
# New points after traversing in direction (0,1) with step size of 0.04346753185484371 is : [1.864556487657498,3.476567684594246]
# New points after traversing in direction (0.016731492617063637,0.043467531854843866) with step size of 0.9999795829617639 is : [1.8812876386670372,3.52003432897083]
#
# *****************Iteration 22***************
# Initial Points : [1.8812876386670372,3.52003432897083]
# New points after traversing in direction (1,0) with step size of 0.006082357981658769 is : [1.8873699966486959,3.52003432897083]
# New points after traversing in direction (0,1) with step size of 0.042133837920566186 is : [1.8873699966486959,3.562168166891396]
# New points after traversing in direction (0.0060823579816586815,0.04213383792056602) with step size of 0.9999795829617639 is : [1.893452230446619,3.6043011445637823]
#
# *****************Iteration 23***************
# Initial Points : [1.893452230446619,3.6043011445637823]
# New points after traversing in direction (1,0) with step size of 0.015759437099732408 is : [1.9092116675463515,3.6043011445637823]
# New points after traversing in direction (0,1) with step size of 0.04079990398665263 is : [1.9092116675463515,3.6451010485504347]
# New points after traversing in direction (0.015759437099732487,0.04079990398665245) with step size of 0.9999795829617639 is : [1.9249707828850542,3.6859001195238874]
#
# *****************Iteration 24***************
# Initial Points : [1.9249707828850542,3.6859001195238874]
# New points after traversing in direction (1,0) with step size of 0.005176336382522748 is : [1.930147119267577,3.6859001195238874]
# New points after traversing in direction (0,1) with step size of 0.039573088091485825 is : [1.930147119267577,3.7254732076153734]
# New points after traversing in direction (0.005176336382522795,0.039573088091485964) with step size of 0.9999795829617639 is : [1.9353233499646418,3.765045487741607]
#
# *****************Iteration 25***************
# Initial Points : [1.9353233499646418,3.765045487741607]
# New points after traversing in direction (1,0) with step size of 0.014919504393480405 is : [1.9502428543581223,3.765045487741607]
# New points after traversing in direction (0,1) with step size of 0.038402182474268895 is : [1.9502428543581223,3.803447670215876]
# New points after traversing in direction (0.014919504393480443,0.038402182474269075) with step size of 0.9999795829617639 is : [1.965162054139511,3.841849068631317]
#
# *****************Iteration 26***************
# Initial Points : [1.965162054139511,3.841849068631317]
# New points after traversing in direction (1,0) with step size of 0.004418140683532277 is : [1.9695801948230431,3.841849068631317]
# New points after traversing in direction (0,1) with step size of 0.03738929288213014 is : [1.9695801948230431,3.879238361513447]
# New points after traversing in direction (0.00441814068353219,0.03738929288213022) with step size of 0.9999795829617639 is : [1.9739982453012281,3.916626891016955]
#
# *****************Iteration 27***************
# Initial Points : [1.9739982453012281,3.916626891016955]
# New points after traversing in direction (1,0) with step size of 0.014211629466099926 is : [1.988209874767328,3.916626891016955]
# New points after traversing in direction (0,1) with step size of 0.0363607412914896 is : [1.988209874767328,3.9529876323084445]
# New points after traversing in direction (0.014211629466099884,0.036360741291489695) with step size of 0.9999795829617639 is : [2.0024212140740456,3.989347631221289]
#
# *****************Iteration 28***************
# Initial Points : [2.0024212140740456,3.989347631221289]
# New points after traversing in direction (1,0) with step size of 0.0037512074135388285 is : [2.0061724214875842,3.989347631221289]
# New points after traversing in direction (0,1) with step size of 0.03538849070476785 is : [2.0061724214875842,4.024736121926057]
# New points after traversing in direction (0.0037512074135386264,0.03538849070476768) with step size of 0.9999795829617639 is : [2.0099235523125776,4.060123890102656]
#
# *****************Iteration 29***************
# Initial Points : [2.0099235523125776,4.060123890102656]
# New points after traversing in direction (1,0) with step size of 0.013585570459566862 is : [2.0235091227721442,4.060123890102656]
# New points after traversing in direction (0,1) with step size of 0.03445724916899913 is : [2.0235091227721442,4.094581139271655]
# New points after traversing in direction (0.013585570459566654,0.03445724916899895) with step size of 0.9999795829617639 is : [2.0370944158545994,4.129037684925681]
#
# *****************Iteration 30***************
# Initial Points : [2.0370944158545994,4.129037684925681]
# New points after traversing in direction (1,0) with step size of 0.0031660288764473925 is : [2.0402604447310466,4.129037684925681]
# New points after traversing in direction (0,1) with step size of 0.033617382946988836 is : [2.0402604447310466,4.16265506787267]
# New points after traversing in direction (0.0031660288764472355,0.03361738294698924) with step size of 0.9999795829617639 is : [2.0434264089665612,4.196271764452266]
#
# *****************Iteration 31***************
# Initial Points : [2.0434264089665612,4.196271764452266]
# New points after traversing in direction (1,0) with step size of 0.013041270924336601 is : [2.056467679890898,4.196271764452266]
# New points after traversing in direction (0,1) with step size of 0.03277737754287839 is : [2.056467679890898,4.229049141995144]
# New points after traversing in direction (0.013041270924336601,0.03277737754287813) with step size of 0.9999795829617639 is : [2.0695086845511073,4.261825850321052]
#
# *****************Iteration 32***************
# Initial Points : [2.0695086845511073,4.261825850321052]
# New points after traversing in direction (1,0) with step size of 0.002631370925140982 is : [2.072140055476248,4.261825850321052]
# New points after traversing in direction (0,1) with step size of 0.03193753141375248 is : [2.072140055476248,4.293763381734804]
# New points after traversing in direction (0.0026313709251408746,0.03193753141375222) with step size of 0.7873810376942925 is : [2.074211947045844,4.3189103883607585]
#
# *****************Iteration 33***************
# Initial Points : [2.074211947045844,4.3189103883607585]
# New points after traversing in direction (1,0) with step size of 0.011518801762654997 is : [2.085730748808499,4.3189103883607585]
# New points after traversing in direction (0,1) with step size of 0.0313520133086605 is : [2.085730748808499,4.350262401669419]
# New points after traversing in direction (0.011518801762655073,0.03135201330866089) with step size of 0.9999795829617639 is : [2.097249315391338,4.381613774862826]
#
# *****************Iteration 34***************
# Initial Points : [2.097249315391338,4.381613774862826]
# New points after traversing in direction (1,0) with step size of 0.0032729657265984863 is : [2.1005222811179367,4.381613774862826]
# New points after traversing in direction (0,1) with step size of 0.030578227398981393 is : [2.1005222811179367,4.412192002261808]
# New points after traversing in direction (0.003272965726598631,0.03057822739898164) with step size of 0.9999795829617639 is : [2.1037951800202688,4.442769605343951]
#
# *****************Iteration 35***************
# Initial Points : [2.1037951800202688,4.442769605343951]
# New points after traversing in direction (1,0) with step size of 0.01106584356498045 is : [2.114861023585249,4.442769605343951]
# New points after traversing in direction (0,1) with step size of 0.029860794541689013 is : [2.114861023585249,4.47263039988564]
# New points after traversing in direction (0.011065843564980415,0.029860794541688662) with step size of 0.9999795829617639 is : [2.1259266412184785,4.502490584758345]
#
# *****************Iteration 36***************
# Initial Points : [2.1259266412184785,4.502490584758345]
# New points after traversing in direction (1,0) with step size of 0.0028452221629289383 is : [2.1287718633814077,4.502490584758345]
# New points after traversing in direction (0,1) with step size of 0.029178310692845575 is : [2.1287718633814077,4.53166889545119]
# New points after traversing in direction (0.0028452221629291508,0.0291783106928456) with step size of 0.9999795829617639 is : [2.131617027453327,4.560846610409351]
#
# *****************Iteration 37***************
# Initial Points : [2.131617027453327,4.560846610409351]
# New points after traversing in direction (1,0) with step size of 0.010669316420762135 is : [2.142286343874089,4.560846610409351]
# New points after traversing in direction (0,1) with step size of 0.028552274149187238 is : [2.142286343874089,4.5893988845585385]
# New points after traversing in direction (0.010669316420762076,0.028552274149187262) with step size of 0.9999795829617639 is : [2.15295544245901,4.617950575754853]
#
# *****************Iteration 38***************
# Initial Points : [2.15295544245901,4.617950575754853]
# New points after traversing in direction (1,0) with step size of 0.002483518725185827 is : [2.1554389611841955,4.617950575754853]
# New points after traversing in direction (0,1) with step size of 0.0279671219132096 is : [2.1554389611841955,4.645917697668063]
# New points after traversing in direction (0.002483518725185707,0.027967121913209603) with step size of 0.9999795829617639 is : [2.1579224292032846,4.673884248575475]
#
# *****************Iteration 39***************
# Initial Points : [2.1579224292032846,4.673884248575475]
# New points after traversing in direction (1,0) with step size of 0.010332562208216284 is : [2.168254991411501,4.673884248575475]
# New points after traversing in direction (0,1) with step size of 0.02744709682354876 is : [2.168254991411501,4.701331345399024]
# New points after traversing in direction (0.010332562208216434,0.027447096823548733) with step size of 0.9999795829617639 is : [2.1785873426594,4.728777881834147]
#
# *****************Iteration 40***************
# Initial Points : [2.1785873426594,4.728777881834147]
# New points after traversing in direction (1,0) with step size of 0.0021531029357825136 is : [2.180740445595182,4.728777881834147]
# New points after traversing in direction (0,1) with step size of 0.026846274913895424 is : [2.180740445595182,4.755624156748042]
# New points after traversing in direction (0.002153102935782414,0.02684627491389513) with step size of 0.8260502009151288 is : [2.182519016707876,4.777800527534488]
#
# *****************Iteration 41***************
# Initial Points : [2.182519016707876,4.777800527534488]
# New points after traversing in direction (1,0) with step size of 0.009310012405991039 is : [2.191829029113867,4.777800527534488]
# New points after traversing in direction (0,1) with step size of 0.02631161459143212 is : [2.191829029113867,4.80411214212592]
# New points after traversing in direction (0.009310012405991053,0.02631161459143172) with step size of 0.9999795829617639 is : [2.201138851436979,4.83042321951211]
#
# *****************Iteration 42***************
# Initial Points : [2.201138851436979,4.83042321951211]
# New points after traversing in direction (1,0) with step size of 0.0025400449363209825 is : [2.2036788963733,4.83042321951211]
# New points after traversing in direction (0,1) with step size of 0.025767290220780923 is : [2.2036788963733,4.856190509732891]
# New points after traversing in direction (0.0025400449363210953,0.025767290220780836) with step size of 0.9999795829617639 is : [2.2062188894494263,4.881957273861922]
#
# *****************Iteration 43***************
# Initial Points : [2.2062188894494263,4.881957273861922]
# New points after traversing in direction (1,0) with step size of 0.009014339046316402 is : [2.215233228495743,4.881957273861922]
# New points after traversing in direction (0,1) with step size of 0.02528895337216359 is : [2.215233228495743,4.9072462272340855]
# New points after traversing in direction (0.009014339046316433,0.025288953372163192) with step size of 0.9999795829617639 is : [2.224247383495954,4.932534664280721]
#
# *****************Iteration 44***************
# Initial Points : [2.224247383495954,4.932534664280721]
# New points after traversing in direction (1,0) with step size of 0.00226002353209436 is : [2.2265074070280484,4.932534664280721]
# New points after traversing in direction (0,1) with step size of 0.024795153424953212 is : [2.2265074070280484,4.9573298177056735]
# New points after traversing in direction (0.002260023532094202,0.024795153424952865) with step size of 0.9999795829617639 is : [2.228767384417156,4.982124464887031]
#
# *****************Iteration 45***************
# Initial Points : [2.228767384417156,4.982124464887031]
# New points after traversing in direction (1,0) with step size of 0.008750002103689099 is : [2.237517386520845,4.982124464887031]
# New points after traversing in direction (0,1) with step size of 0.02436739507147255 is : [2.237517386520845,5.006491859958503]
# New points after traversing in direction (0.008750002103689258,0.02436739507147223) with step size of 0.9999795829617639 is : [2.246267209975407,5.030858757519939]
#
# *****************Iteration 46***************
# Initial Points : [2.246267209975407,5.030858757519939]
# New points after traversing in direction (1,0) with step size of 0.002005311918607918 is : [2.2482725218940147,5.030858757519939]
# New points after traversing in direction (0,1) with step size of 0.023873575032989904 is : [2.2482725218940147,5.054732332552929]
# New points after traversing in direction (0.002005311918607866,0.023873575032990146) with step size of 0.9737136239713632 is : [2.2502251214294753,5.077978357815454]
#
# *****************Iteration 47***************
# Initial Points : [2.2502251214294753,5.077978357815454]
# New points after traversing in direction (1,0) with step size of 0.008413565902316365 is : [2.258638687331792,5.077978357815454]
# New points after traversing in direction (0,1) with step size of 0.02346110276090109 is : [2.258638687331792,5.101439460576355]
# New points after traversing in direction (0.008413565902316567,0.023461102760901298) with step size of 0.9999795829617639 is : [2.2670520814540116,5.124900084331024]
#
# *****************Iteration 48***************
# Initial Points : [2.2670520814540116,5.124900084331024]
# New points after traversing in direction (1,0) with step size of 0.0018575347850594167 is : [2.268909616239071,5.124900084331024]
# New points after traversing in direction (0,1) with step size of 0.023048956176103048 is : [2.268909616239071,5.147949040507127]
# New points after traversing in direction (0.001857534785059567,0.02304895617610292) with step size of 0.9062852907687435 is : [2.2705930726918617,5.168837970457102]
#
# *****************Iteration 49***************
# Initial Points : [2.2705930726918617,5.168837970457102]
# New points after traversing in direction (1,0) with step size of 0.007894496349826818 is : [2.2784875690416886,5.168837970457102]
# New points after traversing in direction (0,1) with step size of 0.02266205436044229 is : [2.2784875690416886,5.191500024817544]
# New points after traversing in direction (0.007894496349826863,0.022662054360441886) with step size of 0.9999795829617639 is : [2.2863819042092817,5.214161616485955]
#
# *****************Iteration 50***************
# Initial Points : [2.2863819042092817,5.214161616485955]
# New points after traversing in direction (1,0) with step size of 0.0019236198399271648 is : [2.2883055240492087,5.214161616485955]
# New points after traversing in direction (0,1) with step size of 0.02218371751182496 is : [2.2883055240492087,5.236345333997781]
# New points after traversing in direction (0.0019236198399270599,0.02218371751182513) with step size of 0.9999795829617639 is : [2.290229104614516,5.258528598583797]
#
# *****************Iteration 51***************
# Initial Points : [2.290229104614516,5.258528598583797]
# New points after traversing in direction (1,0) with step size of 0.0076806451120388615 is : [2.297909749726555,5.258528598583797]
# New points after traversing in direction (0,1) with step size of 0.021862923215794177 is : [2.297909749726555,5.280391521799591]
# New points after traversing in direction (0.007680645112039031,0.021862923215794083) with step size of 0.9999795829617639 is : [2.305590238022569,5.302253998639245]
#
# *****************Iteration 52***************
# Initial Points : [2.305590238022569,5.302253998639245]
# New points after traversing in direction (1,0) with step size of 0.0017253570009560717 is : [2.3073155950235247,5.302253998639245]
# New points after traversing in direction (0,1) with step size of 0.021450780466181166 is : [2.3073155950235247,5.323704779105427]
# New points after traversing in direction (0.001725357000955885,0.021450780466181207) with step size of 0.9367698020548152 is : [2.308931857359784,5.343799222476653]
#
# *****************Iteration 53***************
# Initial Points : [2.308931857359784,5.343799222476653]
# New points after traversing in direction (1,0) with step size of 0.0072840591561968825 is : [2.3162159165159806,5.343799222476653]
# New points after traversing in direction (0,1) with step size of 0.02106390732337437 is : [2.3162159165159806,5.364863129800027]
# New points after traversing in direction (0.007284059156196676,0.021063907323374487) with step size of 0.9999795829617639 is : [2.3234998269532627,5.3859266070608]
#
# *****************Iteration 54***************
# Initial Points : [2.3234998269532627,5.3859266070608]
# New points after traversing in direction (1,0) with step size of 0.0017253570009560717 is : [2.3252251839542186,5.3859266070608]
# New points after traversing in direction (0,1) with step size of 0.020743100609855916 is : [2.3252251839542186,5.406669707670656]
# New points after traversing in direction (0.001725357000955885,0.020743100609855958) with step size of 0.9999795829617639 is : [2.3269505057284947,5.427412384767834]
#
# *****************Iteration 55***************
# Initial Points : [2.3269505057284947,5.427412384767834]
# New points after traversing in direction (1,0) with step size of 0.007095427855041631 is : [2.3340459335835364,5.427412384767834]
# New points after traversing in direction (0,1) with step size of 0.02035615860931745 is : [2.3340459335835364,5.447768543377151]
# New points after traversing in direction (0.007095427855041692,0.020356158609317276) with step size of 0.9999795829617639 is : [2.341141216570956,5.468124286374]
#
# *****************Iteration 56***************
# Initial Points : [2.341141216570956,5.468124286374]
# New points after traversing in direction (1,0) with step size of 0.001552298749298669 is : [2.342693515320255,5.468124286374]
# New points after traversing in direction (0,1) with step size of 0.020076196016714492 is : [2.342693515320255,5.488200482390714]
# New points after traversing in direction (0.0015522987492988527,0.020076196016714398) with step size of 0.888788252076689 is : [2.3440731802123453,5.5060439695567585]
#
# *****************Iteration 57***************
# Initial Points : [2.3440731802123453,5.5060439695567585]
# New points after traversing in direction (1,0) with step size of 0.006617227257859655 is : [2.350690407470205,5.5060439695567585]
# New points after traversing in direction (0,1) with step size of 0.01970469464484188 is : [2.350690407470205,5.5257486642016005]
# New points after traversing in direction (0.006617227257859515,0.019704694644842036) with step size of 0.9999795829617639 is : [2.3573074996238823,5.545452956534938]
#
# *****************Iteration 58***************
# Initial Points : [2.3573074996238823,5.545452956534938]
# New points after traversing in direction (1,0) with step size of 0.0016845128800405747 is : [2.358992012503923,5.545452956534938]
# New points after traversing in direction (0,1) with step size of 0.019383908022595694 is : [2.358992012503923,5.564836864557534]
# New points after traversing in direction (0.0016845128800406783,0.019383908022595264) with step size of 0.9999795829617639 is : [2.3606764909912,5.584220376818138]
#
# *****************Iteration 59***************
# Initial Points : [2.3606764909912,5.584220376818138]
# New points after traversing in direction (1,0) with step size of 0.006443994933049874 is : [2.3671204859242496,5.584220376818138]
# New points after traversing in direction (0,1) with step size of 0.01903786274650465 is : [2.3671204859242496,5.603258239564642]
# New points after traversing in direction (0.0064439949330497015,0.01903786274650443) with step size of 0.9999795829617639 is : [2.3735643492900085,5.622295713614375]
#
# *****************Iteration 60***************
# Initial Points : [2.3735643492900085,5.622295713614375]
# New points after traversing in direction (1,0) with step size of 0.001527060186503312 is : [2.3750914094765117,5.622295713614375]
# New points after traversing in direction (0,1) with step size of 0.01875784134227803 is : [2.3750914094765117,5.641053554956653]
# New points after traversing in direction (0.0015270601865031708,0.018757841342278425) with step size of 0.9999795829617639 is : [2.3766184384849685,5.659811013319368]
#
# *****************Iteration 61***************
# Initial Points : [2.3766184384849685,5.659811013319368]
# New points after traversing in direction (1,0) with step size of 0.006296213961983284 is : [2.3829146524469516,5.659811013319368]
# New points after traversing in direction (0,1) with step size of 0.018477905049622326 is : [2.3829146524469516,5.678288918368991]
# New points after traversing in direction (0.006296213961983099,0.018477905049622656) with step size of 0.9999795829617639 is : [2.3892107378588934,5.69676644615452]
#
# *****************Iteration 62***************
# Initial Points : [2.3892107378588934,5.69676644615452]
# New points after traversing in direction (1,0) with step size of 0.0013792954692759686 is : [2.3905900333281696,5.69676644615452]
# New points after traversing in direction (0,1) with step size of 0.01815710217303871 is : [2.3905900333281696,5.714923548327558]
# New points after traversing in direction (0.001379295469276176,0.018157102173038453) with step size of 0.8965153203250035 is : [2.3918265928476306,5.731201668598394]
#
# *****************Iteration 63***************
# Initial Points : [2.3918265928476306,5.731201668598394]
# New points after traversing in direction (1,0) with step size of 0.005909326030531922 is : [2.3977359188781624,5.731201668598394]
# New points after traversing in direction (0,1) with step size of 0.01794323614710437 is : [2.3977359188781624,5.749144904745498]
# New points after traversing in direction (0.005909326030531847,0.017943236147104358) with step size of 0.9999795829617639 is : [2.403645124257759,5.767087774544864]
#
# *****************Iteration 64***************
# Initial Points : [2.403645124257759,5.767087774544864]
# New points after traversing in direction (1,0) with step size of 0.001511460836474907 is : [2.405156585094234,5.767087774544864]
# New points after traversing in direction (0,1) with step size of 0.017678862857255263 is : [2.405156585094234,5.784766637402119]
# New points after traversing in direction (0.0015114608364750204,0.017678862857255062) with step size of 0.9999795829617639 is : [2.4066680150711552,5.802445139309355]
#
# *****************Iteration 65***************
# Initial Points : [2.4066680150711552,5.802445139309355]
# New points after traversing in direction (1,0) with step size of 0.005761553639519979 is : [2.4124295687106754,5.802445139309355]
# New points after traversing in direction (0,1) with step size of 0.017383314797804434 is : [2.4124295687106754,5.819828454107159]
# New points after traversing in direction (0.005761553639520134,0.017383314797804417) with step size of 0.9999795829617639 is : [2.4181910047163346,5.837211413989161]
#
# *****************Iteration 66***************
# Initial Points : [2.4181910047163346,5.837211413989161]
# New points after traversing in direction (1,0) with step size of 0.0013792954692759686 is : [2.419570300185611,5.837211413989161]
# New points after traversing in direction (0,1) with step size of 0.01710276878122172 is : [2.419570300185611,5.854314182770382]
# New points after traversing in direction (0.001379295469276176,0.0171027687812213) with step size of 0.9999795829617639 is : [2.4209495674937584,5.87141660236372]
#
# *****************Iteration 67***************
# Initial Points : [2.4209495674937584,5.87141660236372]
# New points after traversing in direction (1,0) with step size of 0.005629389737876217 is : [2.4265789572316345,5.87141660236372]
# New points after traversing in direction (0,1) with step size of 0.01686367423810185 is : [2.4265789572316345,5.888280276601821]
# New points after traversing in direction (0.005629389737876078,0.016863674238101645) with step size of 0.9999795829617639 is : [2.432208232034045,5.905143606533641]
#
# *****************Iteration 68***************
# Initial Points : [2.432208232034045,5.905143606533641]
# New points after traversing in direction (1,0) with step size of 0.0012723562479679807 is : [2.433480588282013,5.905143606533641]
# New points after traversing in direction (0,1) with step size of 0.016690652333083006 is : [2.433480588282013,5.921834258866724]
# New points after traversing in direction (0.001272356247968176,0.0166906523330832) with step size of 0.9321577814974484 is : [2.4346666250593936,5.937392580317276]
#
# *****************Iteration 69***************
# Initial Points : [2.4346666250593936,5.937392580317276]
# New points after traversing in direction (1,0) with step size of 0.005364967683678 is : [2.4400315927430714,5.937392580317276]
# New points after traversing in direction (0,1) with step size of 0.01636981548173868 is : [2.4400315927430714,5.953762395799015]
# New points after traversing in direction (0.005364967683677779,0.016369815481739103) with step size of 0.9999795829617639 is : [2.445396450889999,5.9701318770576055]
#
# *****************Iteration 70***************
# Initial Points : [2.445396450889999,5.9701318770576055]
# New points after traversing in direction (1,0) with step size of 0.0012975971819202319 is : [2.446694048071919,5.9701318770576055]
# New points after traversing in direction (0,1) with step size of 0.016171571267763727 is : [2.446694048071919,5.986303448325369]
# New points after traversing in direction (0.0012975971819200183,0.016171571267763696) with step size of 0.9999795829617639 is : [2.4479916187607476,6.002474689417544]
#
# *****************Iteration 71***************
# Initial Points : [2.4479916187607476,6.002474689417544]
# New points after traversing in direction (1,0) with step size of 0.005242415229298762 is : [2.4532340339900465,6.002474689417544]
# New points after traversing in direction (0,1) with step size of 0.01589159625883961 is : [2.4532340339900465,6.018366285676383]
# New points after traversing in direction (0.0052424152292989135,0.015891596258839513) with step size of 0.9999795829617639 is : [2.458476342184753,6.034257557475894]
#
# *****************Iteration 72***************
# Initial Points : [2.458476342184753,6.034257557475894]
# New points after traversing in direction (1,0) with step size of 0.0011810326303048754 is : [2.459657374815058,6.034257557475894]
# New points after traversing in direction (0,1) with step size of 0.01565242518375791 is : [2.459657374815058,6.049909982659652]
# New points after traversing in direction (0.0011810326303050012,0.015652425183757757) with step size of 0.9399416638685647 is : [2.46076747659067,6.064622349230452]
#
# *****************Iteration 73***************
# Initial Points : [2.46076747659067,6.064622349230452]
# New points after traversing in direction (1,0) with step size of 0.005028563991510805 is : [2.465796040582181,6.064622349230452]
# New points after traversing in direction (0,1) with step size of 0.015520261282114148 is : [2.465796040582181,6.080142610512566]
# New points after traversing in direction (0.005028563991510637,0.015520261282114589) with step size of 0.9999795829617639 is : [2.4708245019053083,6.095662554916912]
#
# *****************Iteration 74***************
# Initial Points : [2.4708245019053083,6.095662554916912]
# New points after traversing in direction (1,0) with step size of 0.0012062711931002325 is : [2.4720307730984086,6.095662554916912]
# New points after traversing in direction (0,1) with step size of 0.015265539623463442 is : [2.4720307730984086,6.110928094540376]
# New points after traversing in direction (0.001206271193100239,0.015265539623463553) with step size of 0.9999795829617639 is : [2.473237019663024,6.126193322486733]
#
# *****************Iteration 75***************
# Initial Points : [2.473237019663024,6.126193322486733]
# New points after traversing in direction (1,0) with step size of 0.0049119994398954476 is : [2.4781490191029194,6.126193322486733]
# New points after traversing in direction (0,1) with step size of 0.015026447451723234 is : [2.4781490191029194,6.1412197699384565]
# New points after traversing in direction (0.00491199943989562,0.015026447451723435) with step size of 0.9999795829617639 is : [2.483060918254335,6.1562459105946274]
#
# *****************Iteration 76***************
# Initial Points : [2.483060918254335,6.1562459105946274]
# New points after traversing in direction (1,0) with step size of 0.0010993529679452802 is : [2.4841602712222803,6.1562459105946274]
# New points after traversing in direction (0,1) with step size of 0.014812579054632 is : [2.4841602712222803,6.171058489649259]
# New points after traversing in direction (0.0010993529679454994,0.014812579054631847) with step size of 0.9243974236171304 is : [2.485176510273495,6.184751199564486]
#
# *****************Iteration 77***************
# Initial Points : [2.485176510273495,6.184751199564486]
# New points after traversing in direction (1,0) with step size of 0.004682536435312369 is : [2.4898590467088075,6.184751199564486]
# New points after traversing in direction (0,1) with step size of 0.01463934526426704 is : [2.4898590467088075,6.199390544828753]
# New points after traversing in direction (0.004682536435312468,0.014639345264266801) with step size of 0.9999795829617639 is : [2.4945414875405945,6.214029591200948]
#
# *****************Iteration 78***************
# Initial Points : [2.4945414875405945,6.214029591200948]
# New points after traversing in direction (1,0) with step size of 0.0011401908807690422 is : [2.4956816784213633,6.214029591200948]
# New points after traversing in direction (0,1) with step size of 0.014400244512472186 is : [2.4956816784213633,6.22842983571342]
# New points after traversing in direction (0.0011401908807688876,0.014400244512471794) with step size of 0.9999795829617639 is : [2.4968218460228115,6.242829786215548]
#
# *****************Iteration 79***************
# Initial Points : [2.4968218460228115,6.242829786215548]
# New points after traversing in direction (1,0) with step size of 0.004591162588551119 is : [2.5014130086113626,6.242829786215548]
# New points after traversing in direction (0,1) with step size of 0.01422722881612833 is : [2.5014130086113626,6.257057015031677]
# New points after traversing in direction (0.004591162588551079,0.0142272288161287) with step size of 0.9999795829617639 is : [2.5060040774619714,6.271283953369931]
#
# *****************Iteration 80***************
# Initial Points : [2.5060040774619714,6.271283953369931]
# New points after traversing in direction (1,0) with step size of 0.00105850263880036 is : [2.5070625801007718,6.271283953369931]
# New points after traversing in direction (0,1) with step size of 0.014079435427796837 is : [2.5070625801007718,6.285363388797728]
# New points after traversing in direction (0.0010585026388003627,0.01407943542779666) with step size of 0.9669834901012248 is : [2.5080861346767205,6.298977970406353]
#
# *****************Iteration 81***************
# Initial Points : [2.5080861346767205,6.298977970406353]
# New points after traversing in direction (1,0) with step size of 0.0044433993368789525 is : [2.5125295340135994,6.298977970406353]
# New points after traversing in direction (0,1) with step size of 0.013824740069093386 is : [2.5125295340135994,6.312802710475447]
# New points after traversing in direction (0.004443399336878873,0.013824740069093622) with step size of 0.9999795829617639 is : [2.516972842629424,6.326627168284294]
#
# *****************Iteration 82***************
# Initial Points : [2.516972842629424,6.326627168284294]
# New points after traversing in direction (1,0) with step size of 0.0010176608892645271 is : [2.5179905035186887,6.326627168284294]
# New points after traversing in direction (0,1) with step size of 0.013651649306342873 is : [2.5179905035186887,6.3402788175906375]
# New points after traversing in direction (0.0010176608892646932,0.013651649306343216) with step size of 0.9618933694222546 is : [2.5189693847803927,6.3534102485400865]
#
# *****************Iteration 83***************
# Initial Points : [2.5189693847803927,6.3534102485400865]
# New points after traversing in direction (1,0) with step size of 0.004311215344683873 is : [2.5232806001250765,6.3534102485400865]
# New points after traversing in direction (0,1) with step size of 0.013544728710031026 is : [2.5232806001250765,6.366954977250118]
# New points after traversing in direction (0.004311215344683816,0.013544728710031428) with step size of 0.9999795829617639 is : [2.5275917274475117,6.380499429416905]
#
# *****************Iteration 84***************
# Initial Points : [2.5275917274475117,6.380499429416905]
# New points after traversing in direction (1,0) with step size of 0.0010176608892645271 is : [2.5286093883367764,6.380499429416905]
# New points after traversing in direction (0,1) with step size of 0.013371686713739915 is : [2.5286093883367764,6.393871116130645]
# New points after traversing in direction (0.0010176608892646932,0.013371686713740338) with step size of 0.9999795829617639 is : [2.5296270284484197,6.407242529834146]
#
# *****************Iteration 85***************
# Initial Points : [2.5296270284484197,6.407242529834146]
# New points after traversing in direction (1,0) with step size of 0.004229535682324278 is : [2.533856564130744,6.407242529834146]
# New points after traversing in direction (0,1) with step size of 0.013198677225487794 is : [2.533856564130744,6.420441207059635]
# New points after traversing in direction (0.004229535682324315,0.013198677225488176) with step size of 0.9999795829617639 is : [2.5380860134584764,6.433639614807225]
#
# *****************Iteration 86***************
# Initial Points : [2.5380860134584764,6.433639614807225]
# New points after traversing in direction (1,0) with step size of 0.0009263109716541693 is : [2.5390123244301304,6.433639614807225]
# New points after traversing in direction (0,1) with step size of 0.012934334074185507 is : [2.5390123244301304,6.446573948881411]
# New points after traversing in direction (0.0009263109716539653,0.01293433407418565) with step size of 0.9003294880914126 is : [2.5398463095130532,6.458219111257225]
#
# *****************Iteration 87***************
# Initial Points : [2.5398463095130532,6.458219111257225]
# New points after traversing in direction (1,0) with step size of 0.003965061022706449 is : [2.5438113705357597,6.458219111257225]
# New points after traversing in direction (0,1) with step size of 0.012761275822528107 is : [2.5438113705357597,6.470980387079753]
# New points after traversing in direction (0.00396506102270644,0.012761275822527729) with step size of 0.9999795829617639 is : [2.5477763506036637,6.483741402354824]
#
# *****************Iteration 88***************
# Initial Points : [2.5477763506036637,6.483741402354824]
# New points after traversing in direction (1,0) with step size of 0.0010176608892645271 is : [2.5487940114929284,6.483741402354824]
# New points after traversing in direction (0,1) with step size of 0.01261350873414387 is : [2.5487940114929284,6.496354911088968]
# New points after traversing in direction (0.0010176608892646932,0.012613508734143686) with step size of 0.9999795829617639 is : [2.5498116516045717,6.508968162292621]
#
# *****************Iteration 89***************
# Initial Points : [2.5498116516045717,6.508968162292621]
# New points after traversing in direction (1,0) with step size of 0.003898972130766172 is : [2.5537106237353377,6.508968162292621]
# New points after traversing in direction (0,1) with step size of 0.012465727763077278 is : [2.5537106237353377,6.5214338900556985]
# New points after traversing in direction (0.003898972130766065,0.012465727763077084) with step size of 0.9999795829617639 is : [2.5576095162606407,6.533899363305535]
#
# *****************Iteration 90***************
# Initial Points : [2.5576095162606407,6.533899363305535]
# New points after traversing in direction (1,0) with step size of 0.0009515495344495264 is : [2.5585610657950904,6.533899363305535]
# New points after traversing in direction (0,1) with step size of 0.012333568603970075 is : [2.5585610657950904,6.546232931909505]
# New points after traversing in direction (0.0009515495344496472,0.012333568603970058) with step size of 0.9999795829617639 is : [2.5595125959017166,6.558566248698534]
#
# *****************Iteration 91***************
# Initial Points : [2.5595125959017166,6.558566248698534]
# New points after traversing in direction (1,0) with step size of 0.003842531031201934 is : [2.5633551269329184,6.558566248698534]
# New points after traversing in direction (0,1) with step size of 0.01222663559133707 is : [2.5633551269329184,6.570792884289871]
# ...
# Initial Points : [2.998901777835965,8.993464655342486]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.998922194874201,8.993464655342486]
# New points after traversing in direction (0,1) with step size of 6.125495105981977e-05 is : [2.998922194874201,8.993525910293545]
# New points after traversing in direction (2.041703823607577e-05,6.125495105990808e-05) with step size of 0.6906725092908327 is : [2.998936296361232,8.9935682174043]
#
# *****************Iteration 705***************
# Initial Points : [2.998936296361232,8.9935682174043]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.998956713399468,8.9935682174043]
# New points after traversing in direction (0,1) with step size of 0.00016817554737166626 is : [2.998956713399468,8.993736392951671]
# New points after traversing in direction (2.041703823607577e-05,0.00016817554737080798) with step size of 0.9999795829617639 is : [2.9989771300208488,8.993904565065396]
#
# *****************Iteration 706***************
# Initial Points : [2.9989771300208488,8.993904565065396]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.998997547059085,8.993904565065396]
# New points after traversing in direction (0,1) with step size of 8.64935138551769e-05 is : [2.998997547059085,8.993991058579251]
# New points after traversing in direction (2.041703823607577e-05,8.649351385514592e-05) with step size of 0.9999795829617639 is : [2.9990179636804655,8.994077550327164]
#
# *****************Iteration 707***************
# Initial Points : [2.9990179636804655,8.994077550327164]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9990383807187015,8.994077550327164]
# New points after traversing in direction (0,1) with step size of 0.00015257619734326125 is : [2.9990383807187015,8.994230126524508]
# New points after traversing in direction (2.041703823607577e-05,0.00015257619734398986) with step size of 0.9999795829617639 is : [2.999058797340082,8.994382699606698]
#
# *****************Iteration 708***************
# Initial Points : [2.999058797340082,8.994382699606698]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9990792143783183,8.994382699606698]
# New points after traversing in direction (0,1) with step size of 8.6495885012071e-05 is : [2.9990792143783183,8.99446919549171]
# New points after traversing in direction (2.041703823607577e-05,8.64958850126385e-05) with step size of 0.9999795829617639 is : [2.999099630999699,8.994555689610733]
#
# *****************Iteration 709***************
# Initial Points : [2.999099630999699,8.994555689610733]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.999120048037935,8.994555689610733]
# New points after traversing in direction (0,1) with step size of 0.00016817554737166626 is : [2.999120048037935,8.994723865158104]
# New points after traversing in direction (2.041703823607577e-05,0.00016817554737080798) with step size of 0.9999795829617639 is : [2.9991404646593156,8.994892037271828]
#
# *****************Iteration 710***************
# Initial Points : [2.9991404646593156,8.994892037271828]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9991608816975517,8.994892037271828]
# New points after traversing in direction (0,1) with step size of 8.64935138551769e-05 is : [2.9991608816975517,8.994978530785684]
# New points after traversing in direction (2.041703823607577e-05,8.649351385514592e-05) with step size of 0.9999795829617639 is : [2.9991812983189323,8.995065022533597]
#
# *****************Iteration 711***************
# Initial Points : [2.9991812983189323,8.995065022533597]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9992017153571684,8.995065022533597]
# New points after traversing in direction (0,1) with step size of 0.00015257619734326125 is : [2.9992017153571684,8.99521759873094]
# New points after traversing in direction (2.041703823607577e-05,0.00015257619734398986) with step size of 0.9999795829617639 is : [2.999222131978549,8.99537017181313]
#
# *****************Iteration 712***************
# Initial Points : [2.999222131978549,8.99537017181313]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.999242549016785,8.99537017181313]
# New points after traversing in direction (0,1) with step size of 8.64935138551769e-05 is : [2.999242549016785,8.995456665326985]
# New points after traversing in direction (2.041703823607577e-05,8.649351385514592e-05) with step size of 0.9999795829617639 is : [2.9992629656381657,8.995543157074898]
#
# *****************Iteration 713***************
# Initial Points : [2.9992629656381657,8.995543157074898]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.999283382676402,8.995543157074898]
# New points after traversing in direction (0,1) with step size of 0.00015257619734326125 is : [2.999283382676402,8.995695733272242]
# New points after traversing in direction (2.041703823607577e-05,0.00015257619734398986) with step size of 0.9999795829617639 is : [2.9993037992977825,8.995848306354432]
#
# *****************Iteration 714***************
# Initial Points : [2.9993037992977825,8.995848306354432]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9993242163360185,8.995848306354432]
# New points after traversing in direction (0,1) with step size of 8.6495885012071e-05 is : [2.9993242163360185,8.995934802239445]
# New points after traversing in direction (2.041703823607577e-05,8.64958850126385e-05) with step size of 0.9999795829617639 is : [2.999344632957399,8.996021296358467]
#
# *****************Iteration 715***************
# Initial Points : [2.999344632957399,8.996021296358467]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9993650499956352,8.996021296358467]
# New points after traversing in direction (0,1) with step size of 0.00016817554737166626 is : [2.9993650499956352,8.996189471905838]
# New points after traversing in direction (2.041703823607577e-05,0.00016817554737080798) with step size of 0.8884013464258431 is : [2.9993831885198943,8.996338879288558]
#
# *****************Iteration 716***************
# Initial Points : [2.9993831885198943,8.996338879288558]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9994036055581303,8.996338879288558]
# New points after traversing in direction (0,1) with step size of 8.64935138551769e-05 is : [2.9994036055581303,8.996425372802413]
# New points after traversing in direction (2.041703823607577e-05,8.649351385514592e-05) with step size of 0.9999795829617639 is : [2.999424022179511,8.996511864550326]
#
# *****************Iteration 717***************
# Initial Points : [2.999424022179511,8.996511864550326]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.999444439217747,8.996511864550326]
# New points after traversing in direction (0,1) with step size of 0.00015257619734326125 is : [2.999444439217747,8.99666444074767]
# New points after traversing in direction (2.041703823607577e-05,0.00015257619734398986) with step size of 0.9999795829617639 is : [2.9994648558391277,8.99681701382986]
#
# *****************Iteration 718***************
# Initial Points : [2.9994648558391277,8.99681701382986]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9994852728773638,8.99681701382986]
# New points after traversing in direction (0,1) with step size of 8.6495885012071e-05 is : [2.9994852728773638,8.996903509714873]
# New points after traversing in direction (2.041703823607577e-05,8.64958850126385e-05) with step size of 0.8854030536237473 is : [2.999503350185364,8.996980093435589]
#
# *****************Iteration 719***************
# Initial Points : [2.999503350185364,8.996980093435589]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9995237672236,8.996980093435589]
# New points after traversing in direction (0,1) with step size of 0.00016817554737166626 is : [2.9995237672236,8.99714826898296]
# New points after traversing in direction (2.041703823607577e-05,0.00016817554737080798) with step size of 0.5311280132737343 is : [2.9995346112845556,8.997237591727316]
#
# *****************Iteration 720***************
# Initial Points : [2.9995346112845556,8.997237591727316]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9995550283227916,8.997237591727316]
# New points after traversing in direction (0,1) with step size of 8.6495885012071e-05 is : [2.9995550283227916,8.997324087612329]
# New points after traversing in direction (2.041703823607577e-05,8.64958850126385e-05) with step size of 0.7911783904106207 is : [2.9995711818422404,8.997392521287411]
#
# *****************Iteration 721***************
# Initial Points : [2.9995711818422404,8.997392521287411]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9995915988804764,8.997392521287411]
# New points after traversing in direction (0,1) with step size of 0.00015257619734326125 is : [2.9995915988804764,8.997545097484755]
# New points after traversing in direction (2.041703823607577e-05,0.00015257619734398986) with step size of 0.9999795829617639 is : [2.999612015501857,8.997697670566945]
#
# *****************Iteration 722***************
# Initial Points : [2.999612015501857,8.997697670566945]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.999632432540093,8.997697670566945]
# New points after traversing in direction (0,1) with step size of 8.6495885012071e-05 is : [2.999632432540093,8.997784166451957]
# New points after traversing in direction (2.041703823607577e-05,8.64958850126385e-05) with step size of 0.5106422707649173 is : [2.9996428583428605,8.997828334907092]
#
# *****************Iteration 723***************
# Initial Points : [2.9996428583428605,8.997828334907092]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9996632753810966,8.997828334907092]
# New points after traversing in direction (0,1) with step size of 0.00015257619734326125 is : [2.9996632753810966,8.997980911104436]
# New points after traversing in direction (2.041703823607577e-05,0.00015257619734398986) with step size of 0.9822550582959687 is : [2.9996833301201793,8.998130779846052]
#
# *****************Iteration 724***************
# Initial Points : [2.9996833301201793,8.998130779846052]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9997037471584154,8.998130779846052]
# New points after traversing in direction (0,1) with step size of 8.6495885012071e-05 is : [2.9997037471584154,8.998217275731065]
# New points after traversing in direction (2.041703823607577e-05,8.64958850126385e-05) with step size of 0.4969930583127863 is : [2.99971389428469,8.99826026358549]
#
# *****************Iteration 725***************
# Initial Points : [2.99971389428469,8.99826026358549]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9997343113229262,8.99826026358549]
# New points after traversing in direction (0,1) with step size of 0.00015257619734326125 is : [2.9997343113229262,8.998412839782834]
# New points after traversing in direction (2.041703823607577e-05,0.00015257619734398986) with step size of 0.5881256091608695 is : [2.999746319105976,8.99850257375184]
#
# *****************Iteration 726***************
# Initial Points : [2.999746319105976,8.99850257375184]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.999766736144212,8.99850257375184]
# New points after traversing in direction (0,1) with step size of 8.6495885012071e-05 is : [2.999766736144212,8.998589069636852]
# New points after traversing in direction (2.041703823607577e-05,8.64958850126385e-05) with step size of 0.19915942488986033 is : [2.999770802389805,8.998606296107566]
#
# *****************Iteration 727***************
# Initial Points : [2.999770802389805,8.998606296107566]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.999791219428041,8.998606296107566]
# New points after traversing in direction (0,1) with step size of 0.00015257619734326125 is : [2.999791219428041,8.99875887230491]
# New points after traversing in direction (2.041703823607577e-05,0.00015257619734398986) with step size of 0.2723074712172351 is : [2.999796779140093,8.998800419943377]
#
# *****************Iteration 728***************
# Initial Points : [2.999796779140093,8.998800419943377]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.999817196178329,8.998800419943377]
# New points after traversing in direction (0,1) with step size of 0.00011173444780742811 is : [2.999817196178329,8.998912154391185]
# New points after traversing in direction (2.041703823607577e-05,0.00011173444780787634) with step size of 0.9999795829617639 is : [2.9998376127997095,8.999023886557707]
#
# *****************Iteration 729***************
# Initial Points : [2.9998376127997095,8.999023886557707]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9998580298379456,8.999023886557707]
# New points after traversing in direction (0,1) with step size of 0.0001273337978358331 is : [2.9998580298379456,8.999151220355543]
# New points after traversing in direction (2.041703823607577e-05,0.0001273337978364708) with step size of 0.9999795829617639 is : [2.999878446459326,8.999278551553601]
#
# *****************Iteration 730***************
# Initial Points : [2.999878446459326,8.999278551553601]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9998988634975623,8.999278551553601]
# New points after traversing in direction (0,1) with step size of 0.00011173444780742811 is : [2.9998988634975623,8.99939028600141]
# New points after traversing in direction (2.041703823607577e-05,0.00011173444780787634) with step size of 0.9999795829617639 is : [2.999919280118943,8.99950201816793]
#
# *****************Iteration 731***************
# Initial Points : [2.999919280118943,8.99950201816793]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.999939697157179,8.99950201816793]
# New points after traversing in direction (0,1) with step size of 0.0001273337978358331 is : [2.999939697157179,8.999629351965767]
# New points after traversing in direction (2.041703823607577e-05,0.0001273337978364708) with step size of 0.9999795829617639 is : [2.9999601137785596,8.999756683163826]
#
# *****************Iteration 732***************
# Initial Points : [2.9999601137785596,8.999756683163826]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9999805308167957,8.999756683163826]
# New points after traversing in direction (0,1) with step size of 0.0001273337978358331 is : [2.9999805308167957,8.999884016961662]
# New points after traversing in direction (2.041703823607577e-05,0.0001273337978364708) with step size of 0.6365200230739217 is : [2.999993526670445,8.9999650674736]
#
# *****************Iteration 733***************
# Initial Points : [2.999993526670445,8.9999650674736]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [3.000013943708681,8.9999650674736]
# New points after traversing in direction (0,1) with step size of 0.00011173444780742811 is : [3.000013943708681,9.000076801921407]
# New points after traversing in direction (2.041703823607577e-05,0.00011173444780787634) with step size of 2.0417038236057683e-05 is : [3.0000139441255365,9.000076804202694]

# %%
print("Minima Occurs at : [{},{}]".format(x1,x2))
print("Function Value at Minina : {}".format(function(x1,x2)))
# Out:
# Minima Occurs at : [2.999993526670445,8.9999650674736]
# Function Value at Minina : 1.4877891258568582e-10
