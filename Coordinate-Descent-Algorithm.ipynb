# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khetansarvesh/Convex-Unconstrained-NonLinear-Optimization-Algorithms/blob/main/Coordinate-Descent-Algorithm.ipynb)

# %%
import math

# %%
def golden(m,n,d1,d2,lower_limit_of_interval=0,upper_limit_of_interval=1,critical_interval_length=0.00005):
  
  golden_ratio = 1.618
  L0 = upper_limit_of_interval-lower_limit_of_interval
  no_of_iterations = math.ceil(math.log2(L0/critical_interval_length)/math.log2(golden_ratio) +1 )

  for i in range(no_of_iterations-1):
      x1 = lower_limit_of_interval + (1/golden_ratio**2)*L0
      value_at_x1 = function(m+x1*d1,n+x1*d2)
      x2 = upper_limit_of_interval - (1/golden_ratio**2)*L0
      value_at_x2 = function(m+x2*d1,n+x2*d2)

      if value_at_x2 > value_at_x1:
        lower_limit_of_interval = lower_limit_of_interval
        upper_limit_of_interval = x2
      else:
        lower_limit_of_interval = x1
        upper_limit_of_interval = upper_limit_of_interval

      L0=upper_limit_of_interval-lower_limit_of_interval

  return (lower_limit_of_interval+upper_limit_of_interval)/2

# %%
def cyclic_coordinate_algorithm():
  
  #initial random points initialization
  x1,x2 = 2,3

  iteration_no = 1
  while(True):
      print("*****************Iteration {}***************".format(iteration_no))
      print("Initial Points : [{},{}]".format(x1,x2))

      #traversing in direction (1,0)
      lambda1 = golden(x1,x2,1,0)
      x1_new1 = x1 + lambda1*1
      x2_new1 = x2 + lambda1*0
      print("New points after traversing in direction (1,0) with step size of {} is : [{},{}] ".format(lambda1,x1_new1,x2_new1))
          
      #traversing in direction (0,1)
      lambda2 = golden(x1_new1,x2_new1,0,1)
      x1_new2 = x1_new1 + lambda2*0
      x2_new2 = x2_new1 + lambda2*1
      print("New points after traversing in direction (0,1) with step size of {} is : [{},{}] ".format(lambda2,x1_new2,x2_new2))
      #print("")
      
      #convergence critera
      if (((x1_new2-x1)**2 + (x2_new2-x2)**2)**0.5) < 0.0002:
          break	

      #preparing for next iteration    
      iteration_no = iteration_no + 1
      x1 = x1_new2
      x2 = x2_new2
        
  return x1,x2

# %%
def function(x1,x2):
    return 7*((x1)**4) - 14*((x1)**2)*(x2) + 7*((x2)**2) + (x1)**2 - 6*(x1) + 9

x1,x2 = cyclic_coordinate_algorithm()
# Out:
# *****************Iteration 1***************
# Initial Points : [2,3]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.000020417038236,3.0]
# New points after traversing in direction (0,1) with step size of 0.9999795829617639 is : [2.000020417038236,3.999979582961764]
# *****************Iteration 2***************
# Initial Points : [2.000020417038236,3.999979582961764]
# New points after traversing in direction (1,0) with step size of 0.008775240666484458 is : [2.0087956577047206,3.999979582961764]
# New points after traversing in direction (0,1) with step size of 0.035281570108456006 is : [2.0087956577047206,4.03526115307022]
# *****************Iteration 3***************
# Initial Points : [2.0087956577047206,4.03526115307022]
# New points after traversing in direction (1,0) with step size of 0.008643065253538005 is : [2.0174387229582584,4.03526115307022]
# New points after traversing in direction (0,1) with step size of 0.03480329207393326 is : [2.0174387229582584,4.070064445144153]
# *****************Iteration 4***************
# Initial Points : [2.0174387229582584,4.070064445144153]
# New points after traversing in direction (1,0) with step size of 0.00849524556467596 is : [2.0259339685229345,4.070064445144153]
# New points after traversing in direction (0,1) with step size of 0.034350323830150714 is : [2.0259339685229345,4.104414768974304]
# *****************Iteration 5***************
# Initial Points : [2.0259339685229345,4.104414768974304]
# New points after traversing in direction (1,0) with step size of 0.008347480847448619 is : [2.034281449370383,4.104414768974304]
# New points after traversing in direction (0,1) with step size of 0.03389732307716263 is : [2.034281449370383,4.138312092051467]
# *****************Iteration 6***************
# Initial Points : [2.034281449370383,4.138312092051467]
# New points after traversing in direction (1,0) with step size of 0.008215305434502166 is : [2.042496754804885,4.138312092051467]
# New points after traversing in direction (0,1) with step size of 0.03348521137156048 is : [2.042496754804885,4.171797303423028]
# *****************Iteration 7***************
# Initial Points : [2.042496754804885,4.171797303423028]
# New points after traversing in direction (1,0) with step size of 0.008083137696146332 is : [2.0505798925010317,4.171797303423028]
# New points after traversing in direction (0,1) with step size of 0.033082594953643005 is : [2.0505798925010317,4.204879898376671]
# *****************Iteration 8***************
# Initial Points : [2.0505798925010317,4.204879898376671]
# New points after traversing in direction (1,0) with step size of 0.007960607704641819 is : [2.0585405002056736,4.204879898376671]
# New points after traversing in direction (0,1) with step size of 0.03271129011685375 is : [2.0585405002056736,4.237591188493525]
# *****************Iteration 9***************
# Initial Points : [2.0585405002056736,4.237591188493525]
# New points after traversing in direction (1,0) with step size of 0.007828417503050803 is : [2.0663689177087243,4.237591188493525]
# New points after traversing in direction (0,1) with step size of 0.0322835465531842 is : [2.0663689177087243,4.2698747350467094]
# *****************Iteration 10***************
# Initial Points : [2.0663689177087243,4.2698747350467094]
# New points after traversing in direction (1,0) with step size of 0.007696244462067266 is : [2.0740651621707915,4.2698747350467094]
# New points after traversing in direction (0,1) with step size of 0.031871074281095396 is : [2.0740651621707915,4.301745809327805]
# *****************Iteration 11***************
# Initial Points : [2.0740651621707915,4.301745809327805]
# New points after traversing in direction (1,0) with step size of 0.007589319123218862 is : [2.0816544812940103,4.301745809327805]
# New points after traversing in direction (0,1) with step size of 0.03155026519642004 is : [2.0816544812940103,4.333296074524225]
# *****************Iteration 12***************
# Initial Points : [2.0816544812940103,4.333296074524225]
# New points after traversing in direction (1,0) with step size of 0.007457074852540741 is : [2.089111556146551,4.333296074524225]
# New points after traversing in direction (0,1) with step size of 0.031097306998745498 is : [2.089111556146551,4.36439338152297]
# *****************Iteration 13***************
# Initial Points : [2.089111556146551,4.36439338152297]
# New points after traversing in direction (1,0) with step size of 0.00735014804813716 is : [2.096461704194688,4.36439338152297]
# New points after traversing in direction (0,1) with step size of 0.030751249304000233 is : [2.096461704194688,4.39514463082697]
# *****************Iteration 14***************
# Initial Points : [2.096461704194688,4.39514463082697]
# New points after traversing in direction (1,0) with step size of 0.00724321740666105 is : [2.103704921601349,4.39514463082697]
# New points after traversing in direction (0,1) with step size of 0.03043045500796945 is : [2.103704921601349,4.425575085834939]
# *****************Iteration 15***************
# Initial Points : [2.103704921601349,4.425575085834939]
# New points after traversing in direction (1,0) with step size of 0.007136268139022287 is : [2.110841189740371,4.425575085834939]
# New points after traversing in direction (0,1) with step size of 0.030084295943455467 is : [2.110841189740371,4.4556593817783945]
# *****************Iteration 16***************
# Initial Points : [2.110841189740371,4.4556593817783945]
# New points after traversing in direction (1,0) with step size of 0.007029347542710441 is : [2.1178705372830815,4.4556593817783945]
# New points after traversing in direction (0,1) with step size of 0.02971297959536353 is : [2.1178705372830815,4.485372361373758]
# *****************Iteration 17***************
# Initial Points : [2.1178705372830815,4.485372361373758]
# New points after traversing in direction (1,0) with step size of 0.00692241690123433 is : [2.124792954184316,4.485372361373758]
# New points after traversing in direction (0,1) with step size of 0.02936695203916509 is : [2.124792954184316,4.514739313412924]
# *****************Iteration 18***************
# Initial Points : [2.124792954184316,4.514739313412924]
# New points after traversing in direction (1,0) with step size of 0.0068310909124143305 is : [2.1316240450967303,4.514739313412924]
# New points after traversing in direction (0,1) with step size of 0.02908698944656213 is : [2.1316240450967303,4.543826302859486]
# *****************Iteration 19***************
# Initial Points : [2.1316240450967303,4.543826302859486]
# New points after traversing in direction (1,0) with step size of 0.006749392625058594 is : [2.138373437721789,4.543826302859486]
# New points after traversing in direction (0,1) with step size of 0.028806968042335512 is : [2.138373437721789,4.572633270901822]
# *****************Iteration 20***************
# Initial Points : [2.138373437721789,4.572633270901822]
# New points after traversing in direction (1,0) with step size of 0.006642469657367083 is : [2.145015907379156,4.572633270901822]
# New points after traversing in direction (0,1) with step size of 0.028460952902903795 is : [2.145015907379156,4.601094223804726]
# *****************Iteration 21***************
# Initial Points : [2.145015907379156,4.601094223804726]
# New points after traversing in direction (1,0) with step size of 0.00655091552936172 is : [2.151566822908518,4.601094223804726]
# New points after traversing in direction (0,1) with step size of 0.028140146189385342 is : [2.151566822908518,4.629234369994111]
# *****************Iteration 22***************
# Initial Points : [2.151566822908518,4.629234369994111]
# New points after traversing in direction (1,0) with step size of 0.006469233495845232 is : [2.1580360564043635,4.629234369994111]
# New points after traversing in direction (0,1) with step size of 0.027885442250850007 is : [2.1580360564043635,4.657119812244961]
# *****************Iteration 23***************
# Initial Points : [2.1580360564043635,4.657119812244961]
# New points after traversing in direction (1,0) with step size of 0.006377909878182126 is : [2.1644139662825457,4.657119812244961]
# New points after traversing in direction (0,1) with step size of 0.0275792621907477 is : [2.1644139662825457,4.684699074435708]
# *****************Iteration 24***************
# Initial Points : [2.1644139662825457,4.684699074435708]
# New points after traversing in direction (1,0) with step size of 0.006296213961983284 is : [2.1707101802445288,4.684699074435708]
# New points after traversing in direction (0,1) with step size of 0.02727408733529664 is : [2.1707101802445288,4.711973161771005]
# *****************Iteration 25***************
# Initial Points : [2.1707101802445288,4.711973161771005]
# New points after traversing in direction (1,0) with step size of 0.006204887973163284 is : [2.176915068217692,4.711973161771005]
# New points after traversing in direction (0,1) with step size of 0.026978519184573543 is : [2.176915068217692,4.738951680955578]
# *****************Iteration 26***************
# Initial Points : [2.176915068217692,4.738951680955578]
# New points after traversing in direction (1,0) with step size of 0.00612320831080369 is : [2.183038276528496,4.738951680955578]
# New points after traversing in direction (0,1) with step size of 0.026698507825511184 is : [2.183038276528496,4.765650188781089]
# *****************Iteration 27***************
# Initial Points : [2.183038276528496,4.765650188781089]
# New points after traversing in direction (1,0) with step size of 0.006057115582151341 is : [2.189095392110647,4.765650188781089]
# New points after traversing in direction (0,1) with step size of 0.026500224895267818 is : [2.189095392110647,4.7921504136763575]
# *****************Iteration 28***************
# Initial Points : [2.189095392110647,4.7921504136763575]
# New points after traversing in direction (1,0) with step size of 0.005975404877307936 is : [2.195070796987955,4.7921504136763575]
# New points after traversing in direction (0,1) with step size of 0.026179450689788355 is : [2.195070796987955,4.818329864366146]
# *****************Iteration 29***************
# Initial Points : [2.195070796987955,4.818329864366146]
# New points after traversing in direction (1,0) with step size of 0.005909326030531922 is : [2.200980123018487,4.818329864366146]
# New points after traversing in direction (0,1) with step size of 0.025981186385262083 is : [2.200980123018487,4.844311050751408]
# *****************Iteration 30***************
# Initial Points : [2.200980123018487,4.844311050751408]
# New points after traversing in direction (1,0) with step size of 0.005817994739084216 is : [2.2067981177575713,4.844311050751408]
# New points after traversing in direction (0,1) with step size of 0.025635112436677574 is : [2.2067981177575713,4.869946163188085]
# *****************Iteration 31***************
# Initial Points : [2.2067981177575713,4.869946163188085]
# New points after traversing in direction (1,0) with step size of 0.005761553639519979 is : [2.2125596713970914,4.869946163188085]
# New points after traversing in direction (0,1) with step size of 0.025462096740333718 is : [2.2125596713970914,4.895408259928419]
# *****************Iteration 32***************
# Initial Points : [2.2125596713970914,4.895408259928419]
# New points after traversing in direction (1,0) with step size of 0.005670230021856873 is : [2.2182299014189484,4.895408259928419]
# New points after traversing in direction (0,1) with step size of 0.025141180981151652 is : [2.2182299014189484,4.9205494409095705]
# *****************Iteration 33***************
# Initial Points : [2.2182299014189484,4.9205494409095705]
# New points after traversing in direction (1,0) with step size of 0.005604062226797872 is : [2.2238339636457463,4.9205494409095705]
# New points after traversing in direction (0,1) with step size of 0.024886474671236655 is : [2.2238339636457463,4.945435915580807]
# *****************Iteration 34***************
# Initial Points : [2.2238339636457463,4.945435915580807]
# New points after traversing in direction (1,0) with step size of 0.005537983380021858 is : [2.229371947025768,4.945435915580807]
# New points after traversing in direction (0,1) with step size of 0.024672580878135158 is : [2.229371947025768,4.970108496458942]
# *****************Iteration 35***************
# Initial Points : [2.229371947025768,4.970108496458942]
# New points after traversing in direction (1,0) with step size of 0.0054718983251541104 is : [2.2348438453509223,4.970108496458942]
# New points after traversing in direction (0,1) with step size of 0.02440823535545321 is : [2.2348438453509223,4.994516731814396]
# *****************Iteration 36***************
# Initial Points : [2.2348438453509223,4.994516731814396]
# New points after traversing in direction (1,0) with step size of 0.005415457225589873 is : [2.2402593025765123,4.994516731814396]
# New points after traversing in direction (0,1) with step size of 0.024235222030489015 is : [2.2402593025765123,5.018751953844885]
# *****************Iteration 37***************
# Initial Points : [2.2402593025765123,5.018751953844885]
# New points after traversing in direction (1,0) with step size of 0.005349368333649595 is : [2.245608670910162,5.018751953844885]
# New points after traversing in direction (0,1) with step size of 0.02399610118742189 is : [2.245608670910162,5.042748055032306]
# *****************Iteration 38***************
# Initial Points : [2.245608670910162,5.042748055032306]
# New points after traversing in direction (1,0) with step size of 0.005283288021318405 is : [2.25089195893148,5.042748055032306]
# New points after traversing in direction (0,1) with step size of 0.02376627761635215 is : [2.25089195893148,5.066514332648659]
# *****************Iteration 39***************
# Initial Points : [2.25089195893148,5.066514332648659]
# New points after traversing in direction (1,0) with step size of 0.005217176666503404 is : [2.2561091355979834,5.066514332648659]
# New points after traversing in direction (0,1) with step size of 0.02350194067372485 is : [2.2561091355979834,5.090016273322384]
# *****************Iteration 40***************
# Initial Points : [2.2561091355979834,5.090016273322384]
# New points after traversing in direction (1,0) with step size of 0.00515109398301532 is : [2.2612602295809987,5.090016273322384]
# New points after traversing in direction (0,1) with step size of 0.02328805839345308 is : [2.2612602295809987,5.113304331715836]
# *****************Iteration 41***************
# Initial Points : [2.2612602295809987,5.113304331715836]
# New points after traversing in direction (1,0) with step size of 0.005110243653870399 is : [2.2663704732348693,5.113304331715836]
# New points after traversing in direction (0,1) with step size of 0.023140293676225738 is : [2.2663704732348693,5.136444625392063]
# *****************Iteration 42***************
# Initial Points : [2.2663704732348693,5.136444625392063]
# New points after traversing in direction (1,0) with step size of 0.005044163341539209 is : [2.2714146365764085,5.136444625392063]
# New points after traversing in direction (0,1) with step size of 0.02287595052492345 is : [2.2714146365764085,5.159320575916986]
# *****************Iteration 43***************
# Initial Points : [2.2714146365764085,5.159320575916986]
# New points after traversing in direction (1,0) with step size of 0.005003323057558553 is : [2.276417959633967,5.159320575916986]
# New points after traversing in direction (0,1) with step size of 0.022753377978105397 is : [2.276417959633967,5.182073953895092]
# *****************Iteration 44***************
# Initial Points : [2.276417959633967,5.182073953895092]
# New points after traversing in direction (1,0) with step size of 0.004937238002690805 is : [2.2813551976366577,5.182073953895092]
# New points after traversing in direction (0,1) with step size of 0.022514271018218804 is : [2.2813551976366577,5.20458822491331]
# *****************Iteration 45***************
# Initial Points : [2.2813551976366577,5.20458822491331]
# New points after traversing in direction (1,0) with step size of 0.0048711414365203674 is : [2.286226339073178,5.20458822491331]
# New points after traversing in direction (0,1) with step size of 0.02224994028368324 is : [2.286226339073178,5.226838165196994]
# *****************Iteration 46***************
# Initial Points : [2.286226339073178,5.226838165196994]
# New points after traversing in direction (1,0) with step size of 0.004830303523696605 is : [2.2910566425968746,5.226838165196994]
# New points after traversing in direction (0,1) with step size of 0.022102037849465368 is : [2.2910566425968746,5.248940203046459]
# *****************Iteration 47***************
# Initial Points : [2.2910566425968746,5.248940203046459]
# New points after traversing in direction (1,0) with step size of 0.004764218468828857 is : [2.2958208610657036,5.248940203046459]
# New points after traversing in direction (0,1) with step size of 0.021847323865765773 is : [2.2958208610657036,5.270787526912224]
# *****************Iteration 48***************
# Initial Points : [2.2958208610657036,5.270787526912224]
# New points after traversing in direction (1,0) with step size of 0.004723378184848201 is : [2.3005442392505517,5.270787526912224]
# New points after traversing in direction (0,1) with step size of 0.02171515996412201 is : [2.3005442392505517,5.292502686876347]
# *****************Iteration 49***************
# Initial Points : [2.3005442392505517,5.292502686876347]
# New points after traversing in direction (1,0) with step size of 0.004682536435312369 is : [2.305226775685864,5.292502686876347]
# New points after traversing in direction (0,1) with step size of 0.021567345017796526 is : [2.305226775685864,5.314070031894143]
# *****************Iteration 50***************
# Initial Points : [2.305226775685864,5.314070031894143]
# New points after traversing in direction (1,0) with step size of 0.004632004338086951 is : [2.309858780023951,5.314070031894143]
# New points after traversing in direction (0,1) with step size of 0.021369084549982327 is : [2.309858780023951,5.3354391164441255]
# *****************Iteration 51***************
# Initial Points : [2.309858780023951,5.3354391164441255]
# New points after traversing in direction (1,0) with step size of 0.004575563238522714 is : [2.314434343262474,5.3354391164441255]
# New points after traversing in direction (0,1) with step size of 0.021170827919686216 is : [2.314434343262474,5.356609944363812]
# *****************Iteration 52***************
# Initial Points : [2.314434343262474,5.356609944363812]
# New points after traversing in direction (1,0) with step size of 0.004525083741775105 is : [2.318959427004249,5.356609944363812]
# New points after traversing in direction (0,1) with step size of 0.020956954219023532 is : [2.318959427004249,5.3775668985828355]
# *****************Iteration 53***************
# Initial Points : [2.318959427004249,5.3775668985828355]
# New points after traversing in direction (1,0) with step size of 0.0044842372497027145 is : [2.3234436642539515,5.3775668985828355]
# New points after traversing in direction (0,1) with step size of 0.02083442422751902 is : [2.3234436642539515,5.398401322810354]
# *****************Iteration 54***************
# Initial Points : [2.3234436642539515,5.398401322810354]
# New points after traversing in direction (1,0) with step size of 0.0044433993368789525 is : [2.3278870635908304,5.398401322810354]
# New points after traversing in direction (0,1) with step size of 0.02066133346476851 is : [2.3278870635908304,5.4190626562751225]
# *****************Iteration 55***************
# Initial Points : [2.3278870635908304,5.4190626562751225]
# New points after traversing in direction (1,0) with step size of 0.004377302770708515 is : [2.3322643663615388,5.4190626562751225]
# New points after traversing in direction (0,1) with step size of 0.02039699652214121 is : [2.3322643663615388,5.439459652797264]
# *****************Iteration 56***************
# Initial Points : [2.3322643663615388,5.439459652797264]
# New points after traversing in direction (1,0) with step size of 0.004336456278636124 is : [2.336600822640175,5.439459652797264]
# New points after traversing in direction (0,1) with step size of 0.020249206970521787 is : [2.336600822640175,5.459708859767785]
# *****************Iteration 57***************
# Initial Points : [2.336600822640175,5.459708859767785]
# New points after traversing in direction (1,0) with step size of 0.004311215344683873 is : [2.3409120379848587,5.459708859767785]
# New points after traversing in direction (0,1) with step size of 0.020157875679074084 is : [2.3409120379848587,5.479866735446859]
# *****************Iteration 58***************
# Initial Points : [2.3409120379848587,5.479866735446859]
# New points after traversing in direction (1,0) with step size of 0.004245135032352683 is : [2.345157173017211,5.479866735446859]
# New points after traversing in direction (0,1) with step size of 0.01990317174053875 is : [2.345157173017211,5.499769907187398]
# *****************Iteration 59***************
# Initial Points : [2.345157173017211,5.499769907187398]
# New points after traversing in direction (1,0) with step size of 0.004204297119528921 is : [2.3493614701367402,5.499769907187398]
# New points after traversing in direction (0,1) with step size of 0.019729933207637235 is : [2.3493614701367402,5.519499840395035]
# *****************Iteration 60***************
# Initial Points : [2.3493614701367402,5.519499840395035]
# New points after traversing in direction (1,0) with step size of 0.004179046140412404 is : [2.3535405162771528,5.519499840395035]
# New points after traversing in direction (0,1) with step size of 0.019648253545277643 is : [2.3535405162771528,5.539148093940312]
# *****************Iteration 61***************
# Initial Points : [2.3535405162771528,5.539148093940312]
# New points after traversing in direction (1,0) with step size of 0.004122605040848167 is : [2.357663121318001,5.539148093940312]
# New points after traversing in direction (0,1) with step size of 0.01942475214351119 is : [2.357663121318001,5.558572846083823]
# *****************Iteration 62***************
# Initial Points : [2.357663121318001,5.558572846083823]
# New points after traversing in direction (1,0) with step size of 0.004097364106895916 is : [2.361760485424897,5.558572846083823]
# New points after traversing in direction (0,1) with step size of 0.019343067738615036 is : [2.361760485424897,5.577915913822438]
# *****************Iteration 63***************
# Initial Points : [2.361760485424897,5.577915913822438]
# New points after traversing in direction (1,0) with step size of 0.004056382268989891 is : [2.365816867693887,5.577915913822438]
# New points after traversing in direction (0,1) with step size of 0.01917005678480774 is : [2.365816867693887,5.597085970607246]
# *****************Iteration 64***************
# Initial Points : [2.365816867693887,5.597085970607246]
# New points after traversing in direction (1,0) with step size of 0.004005902772242282 is : [2.369822770466129,5.597085970607246]
# New points after traversing in direction (0,1) with step size of 0.018971773854564375 is : [2.369822770466129,5.61605774446181]
# *****************Iteration 65***************
# Initial Points : [2.369822770466129,5.61605774446181]
# New points after traversing in direction (1,0) with step size of 0.003965061022706449 is : [2.3737878314888357,5.61605774446181]
# New points after traversing in direction (0,1) with step size of 0.018798768203384778 is : [2.3737878314888357,5.634856512665195]
# *****************Iteration 66***************
# Initial Points : [2.3737878314888357,5.634856512665195]
# New points after traversing in direction (1,0) with step size of 0.003924223109882687 is : [2.3777120545987183,5.634856512665195]
# New points after traversing in direction (0,1) with step size of 0.01865091837458652 is : [2.3777120545987183,5.653507431039781]
# *****************Iteration 67***************
# Initial Points : [2.3777120545987183,5.653507431039781]
# New points after traversing in direction (1,0) with step size of 0.003898972130766172 is : [2.3816110267294843,5.653507431039781]
# New points after traversing in direction (0,1) with step size of 0.01856923634107003 is : [2.3816110267294843,5.672076667380851]
# *****************Iteration 68***************
# Initial Points : [2.3816110267294843,5.672076667380851]
# New points after traversing in direction (1,0) with step size of 0.0038581303812303385 is : [2.3854691571107147,5.672076667380851]
# New points after traversing in direction (0,1) with step size of 0.01839619434477892 is : [2.3854691571107147,5.690472861725629]
# *****************Iteration 69***************
# Initial Points : [2.3854691571107147,5.690472861725629]
# New points after traversing in direction (1,0) with step size of 0.0038172924684065765 is : [2.3892864495791213,5.690472861725629]
# New points after traversing in direction (0,1) with step size of 0.018223184856526797 is : [2.3892864495791213,5.708696046582156]
# *****************Iteration 70***************
# Initial Points : [2.3892864495791213,5.708696046582156]
# New points after traversing in direction (1,0) with step size of 0.0037920515344543257 is : [2.3930785011135756,5.708696046582156]
# New points after traversing in direction (0,1) with step size of 0.018131863610243354 is : [2.3930785011135756,5.726827910192399]
# *****************Iteration 71***************
# Initial Points : [2.3930785011135756,5.726827910192399]
# New points after traversing in direction (1,0) with step size of 0.0037512074135388285 is : [2.396829708527114,5.726827910192399]
# New points after traversing in direction (0,1) with step size of 0.01795884170522451 is : [2.396829708527114,5.744786751897624]
# *****************Iteration 72***************
# Initial Points : [2.396829708527114,5.744786751897624]
# New points after traversing in direction (1,0) with step size of 0.0037103671295581724 is : [2.4005400756566724,5.744786751897624]
# New points after traversing in direction (0,1) with step size of 0.017811022016362466 is : [2.4005400756566724,5.762597773913986]
# *****************Iteration 73***************
# Initial Points : [2.4005400756566724,5.762597773913986]
# New points after traversing in direction (1,0) with step size of 0.0036851084762114968 is : [2.404225184132884,5.762597773913986]
# New points after traversing in direction (0,1) with step size of 0.01770410142005062 is : [2.404225184132884,5.780301875334036]
# *****************Iteration 74***************
# Initial Points : [2.404225184132884,5.780301875334036]
# New points after traversing in direction (1,0) with step size of 0.0036442705633877347 is : [2.4078694546962716,5.780301875334036]
# New points after traversing in direction (0,1) with step size of 0.017531081886188675 is : [2.4078694546962716,5.7978329572202245]
# *****************Iteration 75***************
# Initial Points : [2.4078694546962716,5.7978329572202245]
# New points after traversing in direction (1,0) with step size of 0.003619029629435484 is : [2.411488484325707,5.7978329572202245]
# New points after traversing in direction (0,1) with step size of 0.01743975589736867 is : [2.411488484325707,5.815272713117593]
# *****************Iteration 76***************
# Initial Points : [2.411488484325707,5.815272713117593]
# New points after traversing in direction (1,0) with step size of 0.0035781855085199868 is : [2.415066669834227,5.815272713117593]
# New points after traversing in direction (0,1) with step size of 0.017276384156328328 is : [2.415066669834227,5.832549097273921]
# *****************Iteration 77***************
# Initial Points : [2.415066669834227,5.832549097273921]
# New points after traversing in direction (1,0) with step size of 0.003552944574567735 is : [2.418619614408795,5.832549097273921]
# New points after traversing in direction (0,1) with step size of 0.017159209880785956 is : [2.418619614408795,5.849708307154707]
# *****************Iteration 78***************
# Initial Points : [2.418619614408795,5.849708307154707]
# New points after traversing in direction (1,0) with step size of 0.0035121028250319026 is : [2.422131717233827,5.849708307154707]
# New points after traversing in direction (0,1) with step size of 0.017011437489774017 is : [2.422131717233827,5.866719744644481]
# *****************Iteration 79***************
# Initial Points : [2.422131717233827,5.866719744644481]
# New points after traversing in direction (1,0) with step size of 0.0034965034750034972 is : [2.4256282207088304,5.866719744644481]
# New points after traversing in direction (0,1) with step size of 0.016945358642998003 is : [2.4256282207088304,5.883665103287479]
# *****************Iteration 80***************
# Initial Points : [2.4256282207088304,5.883665103287479]
# New points after traversing in direction (1,0) with step size of 0.0034459713777780813 is : [2.4290741920866084,5.883665103287479]
# New points after traversing in direction (0,1) with step size of 0.016731492617063665 is : [2.4290741920866084,5.900396595904542]
# *****************Iteration 81***************
# Initial Points : [2.4290741920866084,5.900396595904542]
# New points after traversing in direction (1,0) with step size of 0.003430372027749676 is : [2.432504564114358,5.900396595904542]
# New points after traversing in direction (0,1) with step size of 0.016690652333083006 is : [2.432504564114358,5.9170872482376256]
# *****************Iteration 82***************
# Initial Points : [2.432504564114358,5.9170872482376256]
# New points after traversing in direction (1,0) with step size of 0.003405129628242248 is : [2.4359096937426004,5.9170872482376256]
# New points after traversing in direction (0,1) with step size of 0.016558436736785927 is : [2.4359096937426004,5.933645684974412]
# *****************Iteration 83***************
# Initial Points : [2.4359096937426004,5.933645684974412]
# New points after traversing in direction (1,0) with step size of 0.003364291715418486 is : [2.4392739854580188,5.933645684974412]
# New points after traversing in direction (0,1) with step size of 0.01641067348511376 is : [2.4392739854580188,5.950056358459525]
# *****************Iteration 84***************
# Initial Points : [2.4392739854580188,5.950056358459525]
# New points after traversing in direction (1,0) with step size of 0.003339050781466235 is : [2.442613036239485,5.950056358459525]
# New points after traversing in direction (0,1) with step size of 0.01630373042687093 is : [2.442613036239485,5.966360088886396]
# *****************Iteration 85***************
# Initial Points : [2.442613036239485,5.966360088886396]
# New points after traversing in direction (1,0) with step size of 0.003298206660550738 is : [2.445911242900036,5.966360088886396]
# New points after traversing in direction (0,1) with step size of 0.01613072093861881 is : [2.445911242900036,5.9824908098250145]
# *****************Iteration 86***************
# Initial Points : [2.445911242900036,5.9824908098250145]
# New points after traversing in direction (1,0) with step size of 0.0032729657265984863 is : [2.4491842086266344,5.9824908098250145]
# New points after traversing in direction (0,1) with step size of 0.016023767834267972 is : [2.4491842086266344,5.998514577659282]
# *****************Iteration 87***************
# Initial Points : [2.4491842086266344,5.998514577659282]
# New points after traversing in direction (1,0) with step size of 0.003257366376570082 is : [2.4524415750032045,5.998514577659282]
# New points after traversing in direction (0,1) with step size of 0.015957688987491957 is : [2.4524415750032045,6.0144722666467745]
# *****************Iteration 88***************
# Initial Points : [2.4524415750032045,6.0144722666467745]
# New points after traversing in direction (1,0) with step size of 0.003232107723223406 is : [2.455673682726428,6.0144722666467745]
# New points after traversing in direction (0,1) with step size of 0.015866357696044255 is : [2.455673682726428,6.030338624342819]
# *****************Iteration 89***************
# Initial Points : [2.455673682726428,6.030338624342819]
# New points after traversing in direction (1,0) with step size of 0.003191269810399644 is : [2.4588649525368274,6.030338624342819]
# New points after traversing in direction (0,1) with step size of 0.015677752694836254 is : [2.4588649525368274,6.046016377037655]
# *****************Iteration 90***************
# Initial Points : [2.4588649525368274,6.046016377037655]
# New points after traversing in direction (1,0) with step size of 0.0031660288764473925 is : [2.4620309814132746,6.046016377037655]
# New points after traversing in direction (0,1) with step size of 0.015586346336981895 is : [2.4620309814132746,6.061602723374637]
# *****************Iteration 91***************
# Initial Points : [2.4620309814132746,6.061602723374637]
# New points after traversing in direction (1,0) with step size of 0.003150423318327253 is : [2.465181404731602,6.061602723374637]
# New points after traversing in direction (0,1) with step size of 0.015520261282114148 is : [2.465181404731602,6.077122984656752]
# *****************Iteration 92***************
# Initial Points : [2.465181404731602,6.077122984656752]
# New points after traversing in direction (1,0) with step size of 0.0031251823843750012 is : [2.468306587115977,6.077122984656752]
# New points after traversing in direction (0,1) with step size of 0.015413330640638039 is : [2.468306587115977,6.09253631529739]
# *****************Iteration 93***************
# Initial Points : [2.468306587115977,6.09253631529739]
# New points after traversing in direction (1,0) with step size of 0.0030999438215796446 is : [2.4714065309375566,6.09253631529739]
# New points after traversing in direction (0,1) with step size of 0.015306410044326191 is : [2.4714065309375566,6.107842725341716]
# *****************Iteration 94***************
# Initial Points : [2.4714065309375566,6.107842725341716]
# New points after traversing in direction (1,0) with step size of 0.003059102072043811 is : [2.4744656330096,6.107842725341716]
# New points after traversing in direction (0,1) with step size of 0.01513336804803508 is : [2.4744656330096,6.1229760933897515]
# *****************Iteration 95***************
# Initial Points : [2.4744656330096,6.1229760933897515]
# New points after traversing in direction (1,0) with step size of 0.0030435027220154067 is : [2.4775091357316157,6.1229760933897515]
# New points after traversing in direction (0,1) with step size of 0.015076926948470841 is : [2.4775091357316157,6.138053020338222]
# *****************Iteration 96***************
# Initial Points : [2.4775091357316157,6.138053020338222]
# New points after traversing in direction (1,0) with step size of 0.0030182517428988913 is : [2.4805273874745146,6.138053020338222]
# New points after traversing in direction (0,1) with step size of 0.014960362396855484 is : [2.4805273874745146,6.153013382735077]
# *****************Iteration 97***************
# Initial Points : [2.4805273874745146,6.153013382735077]
# New points after traversing in direction (1,0) with step size of 0.0029930131801035337 is : [2.4835204006546183,6.153013382735077]
# New points after traversing in direction (0,1) with step size of 0.01485342554670439 is : [2.4835204006546183,6.167866808281781]
# *****************Iteration 98***************
# Initial Points : [2.4835204006546183,6.167866808281781]
# New points after traversing in direction (1,0) with step size of 0.0029774138300751292 is : [2.4864978144846934,6.167866808281781]
# New points after traversing in direction (0,1) with step size of 0.014812579054632 is : [2.4864978144846934,6.182679387336413]
# *****************Iteration 99***************
# Initial Points : [2.4864978144846934,6.182679387336413]
# New points after traversing in direction (1,0) with step size of 0.0029521714305677012 is : [2.489449985915261,6.182679387336413]
# New points after traversing in direction (0,1) with step size of 0.014680187013802876 is : [2.489449985915261,6.197359574350216]
# *****************Iteration 100***************
# Initial Points : [2.489449985915261,6.197359574350216]
# New points after traversing in direction (1,0) with step size of 0.002911333517743939 is : [2.4923613194330048,6.197359574350216]
# New points after traversing in direction (0,1) with step size of 0.01450718136262328 is : [2.4923613194330048,6.2118667557128395]
# *****************Iteration 101***************
# Initial Points : [2.4923613194330048,6.2118667557128395]
# New points after traversing in direction (1,0) with step size of 0.0028860925837916876 is : [2.4952474120167962,6.2118667557128395]
# New points after traversing in direction (0,1) with step size of 0.014400244512472186 is : [2.4952474120167962,6.226267000225311]
# *****************Iteration 102***************
# Initial Points : [2.4952474120167962,6.226267000225311]
# New points after traversing in direction (1,0) with step size of 0.002870460725724296 is : [2.4981178727425206,6.226267000225311]
# New points after traversing in direction (0,1) with step size of 0.014318560107576036 is : [2.4981178727425206,6.240585560332887]
# *****************Iteration 103***************
# Initial Points : [2.4981178727425206,6.240585560332887]
# New points after traversing in direction (1,0) with step size of 0.0028452221629289383 is : [2.5009630949054498,6.240585560332887]
# New points after traversing in direction (0,1) with step size of 0.01422722881612833 is : [2.5009630949054498,6.254812789149016]
# *****************Iteration 104***************
# Initial Points : [2.5009630949054498,6.254812789149016]
# New points after traversing in direction (1,0) with step size of 0.0028199812289766875 is : [2.5037830761344266,6.254812789149016]
# New points after traversing in direction (0,1) with step size of 0.014120308219816483 is : [2.5037830761344266,6.268933097368833]
# *****************Iteration 105***************
# Initial Points : [2.5037830761344266,6.268933097368833]
# New points after traversing in direction (1,0) with step size of 0.002804381878948282 is : [2.506587458013375,6.268933097368833]
# New points after traversing in direction (0,1) with step size of 0.014054196865001482 is : [2.506587458013375,6.282987294233834]
# *****************Iteration 106***************
# Initial Points : [2.506587458013375,6.282987294233834]
# New points after traversing in direction (1,0) with step size of 0.002779139479440854 is : [2.5093665974928157,6.282987294233834]
# New points after traversing in direction (0,1) with step size of 0.013931666873496968 is : [2.5093665974928157,6.296918961107331]
# *****************Iteration 107***************
# Initial Points : [2.5093665974928157,6.296918961107331]
# New points after traversing in direction (1,0) with step size of 0.0027635401294124496 is : [2.5121301376222283,6.296918961107331]
# New points after traversing in direction (0,1) with step size of 0.013890825123961132 is : [2.5121301376222283,6.310809786231292]
# *****************Iteration 108***************
# Initial Points : [2.5121301376222283,6.310809786231292]
# New points after traversing in direction (1,0) with step size of 0.002738301566617092 is : [2.514868439188845,6.310809786231292]
# New points after traversing in direction (0,1) with step size of 0.013758661222317371 is : [2.514868439188845,6.3245684474536095]
# *****************Iteration 109***************
# Initial Points : [2.514868439188845,6.3245684474536095]
# New points after traversing in direction (1,0) with step size of 0.0027130505875005767 is : [2.5175814897763455,6.3245684474536095]
# New points after traversing in direction (0,1) with step size of 0.013651649306342873 is : [2.5175814897763455,6.338220096759953]
# *****************Iteration 110***************
# Initial Points : [2.5175814897763455,6.338220096759953]
# New points after traversing in direction (1,0) with step size of 0.002697451237472172 is : [2.5202789410138178,6.338220096759953]
# New points after traversing in direction (0,1) with step size of 0.013585570459566862 is : [2.5202789410138178,6.351805667219519]
# *****************Iteration 111***************
# Initial Points : [2.5202789410138178,6.351805667219519]
# New points after traversing in direction (1,0) with step size of 0.002672208837964744 is : [2.5229511498517825,6.351805667219519]
# New points after traversing in direction (0,1) with step size of 0.013478639818090752 is : [2.5229511498517825,6.36528430703761]
# *****************Iteration 112***************
# Initial Points : [2.5229511498517825,6.36528430703761]
# New points after traversing in direction (1,0) with step size of 0.0026566094879363388 is : [2.525607759339719,6.36528430703761]
# New points after traversing in direction (0,1) with step size of 0.013412557134602664 is : [2.525607759339719,6.3786968641722135]
# *****************Iteration 113***************
# Initial Points : [2.525607759339719,6.3786968641722135]
# New points after traversing in direction (1,0) with step size of 0.002631370925140982 is : [2.52823913026486,6.3786968641722135]
# New points after traversing in direction (0,1) with step size of 0.013305607866963904 is : [2.52823913026486,6.392002472039177]
# *****************Iteration 114***************
# Initial Points : [2.52823913026486,6.392002472039177]
# New points after traversing in direction (1,0) with step size of 0.002631368553984088 is : [2.530870498818844,6.392002472039177]
# New points after traversing in direction (0,1) with step size of 0.013305607866963904 is : [2.530870498818844,6.405308079906141]
# *****************Iteration 115***************
# Initial Points : [2.530870498818844,6.405308079906141]
# New points after traversing in direction (1,0) with step size of 0.002590524433068591 is : [2.533461023251913,6.405308079906141]
# New points after traversing in direction (0,1) with step size of 0.01310735597920435 is : [2.533461023251913,6.418415435885345]
# *****************Iteration 116***************
# Initial Points : [2.533461023251913,6.418415435885345]
# New points after traversing in direction (1,0) with step size of 0.0025652858702732333 is : [2.536026309122186,6.418415435885345]
# New points after traversing in direction (0,1) with step size of 0.013025671574308197 is : [2.536026309122186,6.431441107459653]
# *****************Iteration 117***************
# Initial Points : [2.536026309122186,6.431441107459653]
# New points after traversing in direction (1,0) with step size of 0.002565283499116339 is : [2.5385915926213025,6.431441107459653]
# New points after traversing in direction (0,1) with step size of 0.013000412920961522 is : [2.5385915926213025,6.4444415203806145]
# *****************Iteration 118***************
# Initial Points : [2.5385915926213025,6.4444415203806145]
# New points after traversing in direction (1,0) with step size of 0.0025400449363209825 is : [2.5411316375576236,6.4444415203806145]
# New points after traversing in direction (0,1) with step size of 0.012918728516065368 is : [2.5411316375576236,6.45736024889668]
# *****************Iteration 119***************
# Initial Points : [2.5411316375576236,6.45736024889668]
# New points after traversing in direction (1,0) with step size of 0.002524445586292577 is : [2.543656083143916,6.45736024889668]
# New points after traversing in direction (0,1) with step size of 0.012827407269781925 is : [2.543656083143916,6.470187656166462]
# *****************Iteration 120***************
# Initial Points : [2.543656083143916,6.470187656166462]
# New points after traversing in direction (1,0) with step size of 0.0024991180752142322 is : [2.5461552012191304,6.470187656166462]
# New points after traversing in direction (0,1) with step size of 0.012720434072992271 is : [2.5461552012191304,6.482908090239454]
# *****************Iteration 121***************
# Initial Points : [2.5461552012191304,6.482908090239454]
# New points after traversing in direction (1,0) with step size of 0.002483518725185827 is : [2.548638719944316,6.482908090239454]
# New points after traversing in direction (0,1) with step size of 0.01265435522621626 is : [2.548638719944316,6.49556244546567]
# *****************Iteration 122***************
# Initial Points : [2.548638719944316,6.49556244546567]
# New points after traversing in direction (1,0) with step size of 0.00245828016239047 is : [2.5510970001067066,6.49556244546567]
# New points after traversing in direction (0,1) with step size of 0.012531812817945027 is : [2.5510970001067066,6.508094258283616]
# *****************Iteration 123***************
# Initial Points : [2.5510970001067066,6.508094258283616]
# New points after traversing in direction (1,0) with step size of 0.002458277791233576 is : [2.55355527789794,6.508094258283616]
# New points after traversing in direction (0,1) with step size of 0.012547412167973431 is : [2.55355527789794,6.520641670451589]
# *****************Iteration 124***************
# Initial Points : [2.55355527789794,6.520641670451589]
# New points after traversing in direction (1,0) with step size of 0.0024330392284382185 is : [2.555988317126378,6.520641670451589]
# New points after traversing in direction (0,1) with step size of 0.012440486829125026 is : [2.555988317126378,6.533082157280714]
# *****************Iteration 125***************
# Initial Points : [2.555988317126378,6.533082157280714]
# New points after traversing in direction (1,0) with step size of 0.002417433670318079 is : [2.5584057507966964,6.533082157280714]
# New points after traversing in direction (0,1) with step size of 0.01235880716676543 is : [2.5584057507966964,6.545440964447479]
# *****************Iteration 126***************
# Initial Points : [2.5584057507966964,6.545440964447479]
# New points after traversing in direction (1,0) with step size of 0.0023921951075227214 is : [2.560797945904219,6.545440964447479]
# New points after traversing in direction (0,1) with step size of 0.01225187652528932 is : [2.560797945904219,6.557692840972769]
# *****************Iteration 127***************
# Initial Points : [2.560797945904219,6.557692840972769]
# New points after traversing in direction (1,0) with step size of 0.0023669541735704706 is : [2.5631649000777896,6.557692840972769]
# New points after traversing in direction (0,1) with step size of 0.012119574906655033 is : [2.5631649000777896,6.569812415879424]
# *****************Iteration 128***************
# Initial Points : [2.5631649000777896,6.569812415879424]
# New points after traversing in direction (1,0) with step size of 0.002351354823542065 is : [2.5655162549013317,6.569812415879424]
# New points after traversing in direction (0,1) with step size of 0.012053494594323842 is : [2.5655162549013317,6.581865910473748]
# *****************Iteration 129***************
# Initial Points : [2.5655162549013317,6.581865910473748]
# New points after traversing in direction (1,0) with step size of 0.002351354823542065 is : [2.567867609724874,6.581865910473748]
# New points after traversing in direction (0,1) with step size of 0.012078733157119197 is : [2.567867609724874,6.593944643630866]
# *****************Iteration 130***************
# Initial Points : [2.567867609724874,6.593944643630866]
# New points after traversing in direction (1,0) with step size of 0.0023261124240346372 is : [2.5701937221489084,6.593944643630866]
# New points after traversing in direction (0,1) with step size of 0.011946563952847732 is : [2.5701937221489084,6.605891207583714]
# *****************Iteration 131***************
# Initial Points : [2.5701937221489084,6.605891207583714]
# New points after traversing in direction (1,0) with step size of 0.0023105130740062327 is : [2.572504235222915,6.605891207583714]
# New points after traversing in direction (0,1) with step size of 0.011880478897979982 is : [2.572504235222915,6.617771686481694]
# *****************Iteration 132***************
# Initial Points : [2.572504235222915,6.617771686481694]
# New points after traversing in direction (1,0) with step size of 0.002285274511210875 is : [2.5747895097341256,6.617771686481694]
# New points after traversing in direction (0,1) with step size of 0.011773539676671996 is : [2.5747895097341256,6.629545226158366]
# *****************Iteration 133***************
# Initial Points : [2.5747895097341256,6.629545226158366]
# New points after traversing in direction (1,0) with step size of 0.0022852620948897173 is : [2.5770747718290155,6.629545226158366]
# ...
# Initial Points : [2.989290062299657,8.935845820668414]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9893357179006883,8.935845820668414]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9893357179006883,8.9361305607674]
# *****************Iteration 1002***************
# Initial Points : [2.9893357179006883,8.9361305607674]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9893813735017196,8.9361305607674]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9893813735017196,8.936390062303593]
# *****************Iteration 1003***************
# Initial Points : [2.9893813735017196,8.936390062303593]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.989427029102751,8.936390062303593]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.989427029102751,8.93667480240258]
# *****************Iteration 1004***************
# Initial Points : [2.989427029102751,8.93667480240258]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9894726847037822,8.93667480240258]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9894726847037822,8.936959542501567]
# *****************Iteration 1005***************
# Initial Points : [2.9894726847037822,8.936959542501567]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9895183403048136,8.936959542501567]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9895183403048136,8.937219044037759]
# *****************Iteration 1006***************
# Initial Points : [2.9895183403048136,8.937219044037759]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.989563995905845,8.937219044037759]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.989563995905845,8.937503784136746]
# *****************Iteration 1007***************
# Initial Points : [2.989563995905845,8.937503784136746]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.989609651506876,8.937503784136746]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.989609651506876,8.937763285672938]
# *****************Iteration 1008***************
# Initial Points : [2.989609651506876,8.937763285672938]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9896553071079075,8.937763285672938]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9896553071079075,8.938048025771925]
# *****************Iteration 1009***************
# Initial Points : [2.9896553071079075,8.938048025771925]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.989700962708939,8.938048025771925]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.989700962708939,8.938307527308117]
# *****************Iteration 1010***************
# Initial Points : [2.989700962708939,8.938307527308117]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.98974661830997,8.938307527308117]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.98974661830997,8.938592267407104]
# *****************Iteration 1011***************
# Initial Points : [2.98974661830997,8.938592267407104]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9897922739110014,8.938592267407104]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9897922739110014,8.938851768943296]
# *****************Iteration 1012***************
# Initial Points : [2.9897922739110014,8.938851768943296]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9898379295120328,8.938851768943296]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9898379295120328,8.939136509042283]
# *****************Iteration 1013***************
# Initial Points : [2.9898379295120328,8.939136509042283]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.989883585113064,8.939136509042283]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.989883585113064,8.939396010578475]
# *****************Iteration 1014***************
# Initial Points : [2.989883585113064,8.939396010578475]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9899292407140954,8.939396010578475]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9899292407140954,8.939680750677462]
# *****************Iteration 1015***************
# Initial Points : [2.9899292407140954,8.939680750677462]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9899748963151267,8.939680750677462]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9899748963151267,8.939940252213654]
# *****************Iteration 1016***************
# Initial Points : [2.9899748963151267,8.939940252213654]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.990020551916158,8.939940252213654]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.990020551916158,8.940224992312642]
# *****************Iteration 1017***************
# Initial Points : [2.990020551916158,8.940224992312642]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9900662075171893,8.940224992312642]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9900662075171893,8.940484493848833]
# *****************Iteration 1018***************
# Initial Points : [2.9900662075171893,8.940484493848833]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9901118631182206,8.940484493848833]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9901118631182206,8.94076923394782]
# *****************Iteration 1019***************
# Initial Points : [2.9901118631182206,8.94076923394782]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.990157518719252,8.94076923394782]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.990157518719252,8.941053974046808]
# *****************Iteration 1020***************
# Initial Points : [2.990157518719252,8.941053974046808]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9902031743202833,8.941053974046808]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9902031743202833,8.941313475583]
# *****************Iteration 1021***************
# Initial Points : [2.9902031743202833,8.941313475583]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9902488299213146,8.941313475583]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9902488299213146,8.941598215681987]
# *****************Iteration 1022***************
# Initial Points : [2.9902488299213146,8.941598215681987]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.990294485522346,8.941598215681987]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.990294485522346,8.941857717218179]
# *****************Iteration 1023***************
# Initial Points : [2.990294485522346,8.941857717218179]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.990340141123377,8.941857717218179]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.990340141123377,8.942142457317166]
# *****************Iteration 1024***************
# Initial Points : [2.990340141123377,8.942142457317166]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9903857967244085,8.942142457317166]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9903857967244085,8.942401958853358]
# *****************Iteration 1025***************
# Initial Points : [2.9903857967244085,8.942401958853358]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.99043145232544,8.942401958853358]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.99043145232544,8.942686698952345]
# *****************Iteration 1026***************
# Initial Points : [2.99043145232544,8.942686698952345]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.990477107926471,8.942686698952345]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.990477107926471,8.942946200488537]
# *****************Iteration 1027***************
# Initial Points : [2.990477107926471,8.942946200488537]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9905227635275025,8.942946200488537]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9905227635275025,8.943230940587524]
# *****************Iteration 1028***************
# Initial Points : [2.9905227635275025,8.943230940587524]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9905684191285338,8.943230940587524]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9905684191285338,8.943490442123716]
# *****************Iteration 1029***************
# Initial Points : [2.9905684191285338,8.943490442123716]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.990614074729565,8.943490442123716]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.990614074729565,8.943775182222703]
# *****************Iteration 1030***************
# Initial Points : [2.990614074729565,8.943775182222703]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9906597303305964,8.943775182222703]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9906597303305964,8.944034683758895]
# *****************Iteration 1031***************
# Initial Points : [2.9906597303305964,8.944034683758895]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9907053859316277,8.944034683758895]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9907053859316277,8.944319423857882]
# *****************Iteration 1032***************
# Initial Points : [2.9907053859316277,8.944319423857882]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.990751041532659,8.944319423857882]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.990751041532659,8.94460416395687]
# *****************Iteration 1033***************
# Initial Points : [2.990751041532659,8.94460416395687]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9907966971336903,8.94460416395687]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9907966971336903,8.944863665493061]
# *****************Iteration 1034***************
# Initial Points : [2.9907966971336903,8.944863665493061]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9908423527347217,8.944863665493061]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9908423527347217,8.945148405592048]
# *****************Iteration 1035***************
# Initial Points : [2.9908423527347217,8.945148405592048]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.990888008335753,8.945148405592048]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.990888008335753,8.94540790712824]
# *****************Iteration 1036***************
# Initial Points : [2.990888008335753,8.94540790712824]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9909336639367843,8.94540790712824]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9909336639367843,8.945692647227228]
# *****************Iteration 1037***************
# Initial Points : [2.9909336639367843,8.945692647227228]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9909793195378156,8.945692647227228]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9909793195378156,8.94595214876342]
# *****************Iteration 1038***************
# Initial Points : [2.9909793195378156,8.94595214876342]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.991024975138847,8.94595214876342]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.991024975138847,8.946236888862407]
# *****************Iteration 1039***************
# Initial Points : [2.991024975138847,8.946236888862407]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9910706307398782,8.946236888862407]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9910706307398782,8.946496390398599]
# *****************Iteration 1040***************
# Initial Points : [2.9910706307398782,8.946496390398599]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9911162863409095,8.946496390398599]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.9911162863409095,8.946781130497586]
# *****************Iteration 1041***************
# Initial Points : [2.9911162863409095,8.946781130497586]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.991161941941941,8.946781130497586]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.991161941941941,8.947040632033778]
# *****************Iteration 1042***************
# Initial Points : [2.991161941941941,8.947040632033778]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.991207597542972,8.947040632033778]
# New points after traversing in direction (0,1) with step size of 0.0002847400989870226 is : [2.991207597542972,8.947325372132765]
# *****************Iteration 1043***************
# Initial Points : [2.991207597542972,8.947325372132765]
# New points after traversing in direction (1,0) with step size of 4.56556010314148e-05 is : [2.9912532531440035,8.947325372132765]
# New points after traversing in direction (0,1) with step size of 0.00025950153619166554 is : [2.9912532531440035,8.947584873668957]
# *****************Iteration 1044***************
# Initial Points : [2.9912532531440035,8.947584873668957]
# New points after traversing in direction (1,0) with step size of 2.0417038236057683e-05 is : [2.9912736701822396,8.947584873668957]
# New points after traversing in direction (0,1) with step size of 0.0001273337978358331 is : [2.9912736701822396,8.947712207466793]

# %%
print("Minima Occurs at : [{},{}]".format(x1,x2))
print("Function Value at Minina : {}".format(function(x1,x2)))
# Out:
# Minima Occurs at : [2.9912532531440035,8.947584873668957]
# Function Value at Minina : 7.650645095047537e-05
