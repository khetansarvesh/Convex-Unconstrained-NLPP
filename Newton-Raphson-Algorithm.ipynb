# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/khetansarvesh/Convex-Unconstrained-NonLinear-Optimization-Algorithms/blob/main/Newton-Raphson-Algorithm.ipynb)

# %%
  #importing required libraries
  import math

# %%
def newton_raphson_algorithm(function,function_first_derivative,initial_random_start_at,threshold_value):
  current_point = initial_random_start_at
  new_point = current_point + 100000000
  i = 0
  #using difference between two values of x as stopping criteria
  while abs(current_point - new_point) > threshold_value:
    if i != 0:
      current_point = new_point
    
    print("*********Iteration {}**********".format(i+1))
    print("Current Point : {}".format(current_point))
    new_point = current_point - (1/function_first_derivative(current_point))*(function(current_point))
    print("New Point : {}".format(new_point))
    i=i+1
    print("")
  optimum_occurs_at = new_point
  return optimum_occurs_at

# %%
#This algorithm is specifically for finding minima of 6e^(-2x) + 2x^2.........change this function if you want to find minima of some other function 
def function(x):
  return (x*x*x)-x-1

#This algorithm is specifically for finding minima of 6e^(-2x) + 2x^2.........change this derivate if you want to find minima of some other function 
def first_derivative(x):
  return 3*x*x-1

x = newton_raphson_algorithm(function,first_derivative,1.5,0.00001)
print("minimum occurs at : {}".format(x))
print("value at minimum point : {}".format(function(x)))
# Out:
# *********Iteration 1**********
# Current Point : 1.5
# New Point : 1.3478260869565217
#
# *********Iteration 2**********
# Current Point : 1.3478260869565217
# New Point : 1.325200398950907
#
# *********Iteration 3**********
# Current Point : 1.325200398950907
# New Point : 1.3247181739990537
#
# *********Iteration 4**********
# Current Point : 1.3247181739990537
# New Point : 1.3247179572447898
#
# minimum occurs at : 1.3247179572447898
# value at minimum point : 1.865174681370263e-13
